# %% [markdown]
# ## Just some basic EDA and a how-to guide. ##

# %%
import re
import os

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# "magic" command to make plots show up in the notebook
# %matplotlib inline 

filepath = '../input/'

# %% [markdown]
# Kaggle changed they way they handle compressed files sometime in 2018.  They automatically uncompress them, and put them in a folder with the same name as the file (but all lowercased).  Here is where they are:

# %%
folders = os.listdir(filepath)
# Skip .xslx file, if we are ever able to upload it...
# Currently can't upload due to conflicts with other versions of the dataset on Kaggle.
folders = [f for f in folders if 'xlsx' not in f]
folders
# Out:
# ['accepted_2007_to_2018q4.csv', 'rejected_2007_to_2018q4.csv']

# %%
os.listdir(filepath + folders[0])
# Out:
# ['accepted_2007_to_2018Q4.csv']

# %%
acc_folder = filepath + [f for f in folders if 'accepted' in f][0]
accepted_fn = acc_folder + '/' + os.listdir(acc_folder)[0]

rej_folder = filepath + [f for f in folders if 'rejected' in f][0]
rejected_fn = rej_folder + '/' + os.listdir(rej_folder)[0]

accepted_fn
# Out:
# '../input/accepted_2007_to_2018q4.csv/accepted_2007_to_2018Q4.csv'

# %%
if os.path.isfile(accepted_fn) and os.path.isfile(rejected_fn):
    print('both paths still point to the actual file; all is good')
else:
    print('Kaggle changed how they handle compressed files again...you need to locate the files')
# Out:
# both paths still point to the actual file; all is good

# %%
# Takes a while to read, because these files are large...give it a minute or so
acc_df = pd.read_csv(accepted_fn)

# this is a dataset with rejected loans from lendingclub
rej_df = pd.read_csv(rejected_fn)
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (0,19,49,59,118,129,130,131,134,135,136,139,145,146,147) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# this is how we can see how many entries are in the dataframe (df)
# it also works for numpy arrays
acc_df.shape
# Out:
# (2260701, 151)

# %%
rej_df.shape
# Out:
# (27648741, 9)

# %%
[col for col in acc_df.columns if 'fico' in col.lower()]
# Out:
# ['fico_range_low',
#  'fico_range_high',
#  'last_fico_range_high',
#  'last_fico_range_low',
#  'sec_app_fico_range_low',
#  'sec_app_fico_range_high']

# %%
# No fico score in rejected loans
[col for col in rej_df.columns if 'fico' in col.lower()]
# Out:
# []

# %%
rej_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27648741 entries, 0 to 27648740
# Data columns (total 9 columns):
# Amount Requested        float64
# Application Date        object
# Loan Title              object
# Risk_Score              float64
# Debt-To-Income Ratio    object
# Zip Code                object
# State                   object
# Employment Length       object
# Policy Code             float64
# dtypes: float64(3), object(6)
# memory usage: 1.9+ GB

# %%
acc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2260701 entries, 0 to 2260700
# Columns: 151 entries, id to settlement_term
# dtypes: float64(113), object(38)
# memory usage: 2.5+ GB

# %%
# this is how many rows pandas will show by default with methods like pd.dataframe.head()
pd.options.display.max_rows
# Out:
# 60

# %%
# we want to increase it, because in this case there are a lot of column names
pd.options.display.max_rows = 1000

# %%
# the .T is transposing the matrix.
# We do this so the 111 column dataframe is easier to read (easier to scroll down than sideways) 
# .head() shows the first few rows of the data
acc_df.head().T
# Out:
#                                                                                             0                        ...                                                                          4
# id                                                                                   68407277                        ...                                                                   68476807
# member_id                                                                                 NaN                        ...                                                                        NaN
# loan_amnt                                                                                3600                        ...                                                                      10400
# funded_amnt                                                                              3600                        ...                                                                      10400
# funded_amnt_inv                                                                          3600                        ...                                                                      10400
# term                                                                                36 months                        ...                                                                  60 months
# int_rate                                                                                13.99                        ...                                                                      22.45
# installment                                                                            123.03                        ...                                                                     289.91
# grade                                                                                       C                        ...                                                                          F
# sub_grade                                                                                  C4                        ...                                                                         F1
# emp_title                                                                             leadman                        ...                                                        Contract Specialist
# emp_length                                                                          10+ years                        ...                                                                    3 years
# home_ownership                                                                       MORTGAGE                        ...                                                                   MORTGAGE
# annual_inc                                                                              55000                        ...                                                                     104433
# verification_status                                                              Not Verified                        ...                                                            Source Verified
# issue_d                                                                              Dec-2015                        ...                                                                   Dec-2015
# loan_status                                                                        Fully Paid                        ...                                                                 Fully Paid
# pymnt_plan                                                                                  n                        ...                                                                          n
# url                                         https://lendingclub.com/browse/loanDetail.acti...                        ...                          https://lendingclub.com/browse/loanDetail.acti...
# desc                                                                                      NaN                        ...                                                                        NaN
# purpose                                                                    debt_consolidation                        ...                                                             major_purchase
# title                                                                      Debt consolidation                        ...                                                             Major purchase
# zip_code                                                                                190xx                        ...                                                                      174xx
# addr_state                                                                                 PA                        ...                                                                         PA
# dti                                                                                      5.91                        ...                                                                      25.37
# delinq_2yrs                                                                                 0                        ...                                                                          1
# earliest_cr_line                                                                     Aug-2003                        ...                                                                   Jun-1998
# fico_range_low                                                                            675                        ...                                                                        695
# fico_range_high                                                                           679                        ...                                                                        699
# inq_last_6mths                                                                              1                        ...                                                                          3
# mths_since_last_delinq                                                                     30                        ...                                                                         12
# mths_since_last_record                                                                    NaN                        ...                                                                        NaN
# open_acc                                                                                    7                        ...                                                                         12
# pub_rec                                                                                     0                        ...                                                                          0
# revol_bal                                                                                2765                        ...                                                                      21929
# revol_util                                                                               29.7                        ...                                                                       64.5
# total_acc                                                                                  13                        ...                                                                         35
# initial_list_status                                                                         w                        ...                                                                          w
# out_prncp                                                                                   0                        ...                                                                          0
# out_prncp_inv                                                                               0                        ...                                                                          0
# total_pymnt                                                                           4421.72                        ...                                                                    11740.5
# total_pymnt_inv                                                                       4421.72                        ...                                                                    11740.5
# total_rec_prncp                                                                          3600                        ...                                                                      10400
# total_rec_int                                                                          821.72                        ...                                                                     1340.5
# total_rec_late_fee                                                                          0                        ...                                                                          0
# recoveries                                                                                  0                        ...                                                                          0
# collection_recovery_fee                                                                     0                        ...                                                                          0
# last_pymnt_d                                                                         Jan-2019                        ...                                                                   Jul-2016
# last_pymnt_amnt                                                                        122.67                        ...                                                                      10129
# next_pymnt_d                                                                              NaN                        ...                                                                        NaN
# last_credit_pull_d                                                                   Mar-2019                        ...                                                                   Mar-2018
# last_fico_range_high                                                                      564                        ...                                                                        704
# last_fico_range_low                                                                       560                        ...                                                                        700
# collections_12_mths_ex_med                                                                  0                        ...                                                                          0
# mths_since_last_major_derog                                                                30                        ...                                                                        NaN
# policy_code                                                                                 1                        ...                                                                          1
# application_type                                                                   Individual                        ...                                                                 Individual
# annual_inc_joint                                                                          NaN                        ...                                                                        NaN
# dti_joint                                                                                 NaN                        ...                                                                        NaN
# verification_status_joint                                                                 NaN                        ...                                                                        NaN
# acc_now_delinq                                                                              0                        ...                                                                          0
# tot_coll_amt                                                                              722                        ...                                                                          0
# tot_cur_bal                                                                            144904                        ...                                                                     331730
# open_acc_6m                                                                                 2                        ...                                                                          1
# open_act_il                                                                                 2                        ...                                                                          3
# open_il_12m                                                                                 0                        ...                                                                          0
# open_il_24m                                                                                 1                        ...                                                                          3
# mths_since_rcnt_il                                                                         21                        ...                                                                         14
# total_bal_il                                                                             4981                        ...                                                                      73839
# il_util                                                                                    36                        ...                                                                         84
# open_rv_12m                                                                                 3                        ...                                                                          4
# open_rv_24m                                                                                 3                        ...                                                                          7
# max_bal_bc                                                                                722                        ...                                                                       9702
# all_util                                                                                   34                        ...                                                                         78
# total_rev_hi_lim                                                                         9300                        ...                                                                      34000
# inq_fi                                                                                      3                        ...                                                                          2
# total_cu_tl                                                                                 1                        ...                                                                          1
# inq_last_12m                                                                                4                        ...                                                                          3
# acc_open_past_24mths                                                                        4                        ...                                                                         10
# avg_cur_bal                                                                             20701                        ...                                                                      27644
# bc_open_to_buy                                                                           1506                        ...                                                                       4567
# bc_util                                                                                  37.2                        ...                                                                       77.5
# chargeoff_within_12_mths                                                                    0                        ...                                                                          0
# delinq_amnt                                                                                 0                        ...                                                                          0
# mo_sin_old_il_acct                                                                        148                        ...                                                                        128
# mo_sin_old_rev_tl_op                                                                      128                        ...                                                                        210
# mo_sin_rcnt_rev_tl_op                                                                       3                        ...                                                                          4
# mo_sin_rcnt_tl                                                                              3                        ...                                                                          4
# mort_acc                                                                                    1                        ...                                                                          6
# mths_since_recent_bc                                                                        4                        ...                                                                          4
# mths_since_recent_bc_dlq                                                                   69                        ...                                                                         12
# mths_since_recent_inq                                                                       4                        ...                                                                          1
# mths_since_recent_revol_delinq                                                             69                        ...                                                                         12
# num_accts_ever_120_pd                                                                       2                        ...                                                                          0
# num_actv_bc_tl                                                                              2                        ...                                                                          4
# num_actv_rev_tl                                                                             4                        ...                                                                          6
# num_bc_sats                                                                                 2                        ...                                                                          5
# num_bc_tl                                                                                   5                        ...                                                                          9
# num_il_tl                                                                                   3                        ...                                                                         10
# num_op_rev_tl                                                                               4                        ...                                                                          7
# num_rev_accts                                                                               9                        ...                                                                         19
# num_rev_tl_bal_gt_0                                                                         4                        ...                                                                          6
# num_sats                                                                                    7                        ...                                                                         12
# num_tl_120dpd_2m                                                                            0                        ...                                                                          0
# num_tl_30dpd                                                                                0                        ...                                                                          0
# num_tl_90g_dpd_24m                                                                          0                        ...                                                                          0
# num_tl_op_past_12m                                                                          3                        ...                                                                          4
# pct_tl_nvr_dlq                                                                           76.9                        ...                                                                       96.6
# percent_bc_gt_75                                                                            0                        ...                                                                         60
# pub_rec_bankruptcies                                                                        0                        ...                                                                          0
# tax_liens                                                                                   0                        ...                                                                          0
# tot_hi_cred_lim                                                                        178050                        ...                                                                     439570
# total_bal_ex_mort                                                                        7746                        ...                                                                      95768
# total_bc_limit                                                                           2400                        ...                                                                      20300
# total_il_high_credit_limit                                                              13734                        ...                                                                      88097
# revol_bal_joint                                                                           NaN                        ...                                                                        NaN
# sec_app_fico_range_low                                                                    NaN                        ...                                                                        NaN
# sec_app_fico_range_high                                                                   NaN                        ...                                                                        NaN
# sec_app_earliest_cr_line                                                                  NaN                        ...                                                                        NaN
# sec_app_inq_last_6mths                                                                    NaN                        ...                                                                        NaN
# sec_app_mort_acc                                                                          NaN                        ...                                                                        NaN
# sec_app_open_acc                                                                          NaN                        ...                                                                        NaN
# sec_app_revol_util                                                                        NaN                        ...                                                                        NaN
# sec_app_open_act_il                                                                       NaN                        ...                                                                        NaN
# sec_app_num_rev_accts                                                                     NaN                        ...                                                                        NaN
# sec_app_chargeoff_within_12_mths                                                          NaN                        ...                                                                        NaN
# sec_app_collections_12_mths_ex_med                                                        NaN                        ...                                                                        NaN
# sec_app_mths_since_last_major_derog                                                       NaN                        ...                                                                        NaN
# hardship_flag                                                                               N                        ...                                                                          N
# hardship_type                                                                             NaN                        ...                                                                        NaN
# hardship_reason                                                                           NaN                        ...                                                                        NaN
# hardship_status                                                                           NaN                        ...                                                                        NaN
# deferral_term                                                                             NaN                        ...                                                                        NaN
# hardship_amount                                                                           NaN                        ...                                                                        NaN
# hardship_start_date                                                                       NaN                        ...                                                                        NaN
# hardship_end_date                                                                         NaN                        ...                                                                        NaN
# payment_plan_start_date                                                                   NaN                        ...                                                                        NaN
# hardship_length                                                                           NaN                        ...                                                                        NaN
# hardship_dpd                                                                              NaN                        ...                                                                        NaN
# hardship_loan_status                                                                      NaN                        ...                                                                        NaN
# orig_projected_additional_accrued_interest                                                NaN                        ...                                                                        NaN
# hardship_payoff_balance_amount                                                            NaN                        ...                                                                        NaN
# hardship_last_payment_amount                                                              NaN                        ...                                                                        NaN
# disbursement_method                                                                      Cash                        ...                                                                       Cash
# debt_settlement_flag                                                                        N                        ...                                                                          N
# debt_settlement_flag_date                                                                 NaN                        ...                                                                        NaN
# settlement_status                                                                         NaN                        ...                                                                        NaN
# settlement_date                                                                           NaN                        ...                                                                        NaN
# settlement_amount                                                                         NaN                        ...                                                                        NaN
# settlement_percentage                                                                     NaN                        ...                                                                        NaN
# settlement_term                                                                           NaN                        ...                                                                        NaN
#
# [151 rows x 5 columns]

# %%
# .tail() shows the last few rows
acc_df.tail().T
# Out:
#                                                                                       2260696                       ...                                                                 2260700
# id                                                                                   88985880                       ...                         Total amount funded in policy code 2: 521953170
# member_id                                                                                 NaN                       ...                                                                     NaN
# loan_amnt                                                                               40000                       ...                                                                     NaN
# funded_amnt                                                                             40000                       ...                                                                     NaN
# funded_amnt_inv                                                                         40000                       ...                                                                     NaN
# term                                                                                60 months                       ...                                                                     NaN
# int_rate                                                                                10.49                       ...                                                                     NaN
# installment                                                                            859.56                       ...                                                                     NaN
# grade                                                                                       B                       ...                                                                     NaN
# sub_grade                                                                                  B3                       ...                                                                     NaN
# emp_title                                                                     Vice President                        ...                                                                     NaN
# emp_length                                                                            9 years                       ...                                                                     NaN
# home_ownership                                                                       MORTGAGE                       ...                                                                     NaN
# annual_inc                                                                             227000                       ...                                                                     NaN
# verification_status                                                                  Verified                       ...                                                                     NaN
# issue_d                                                                              Oct-2016                       ...                                                                     NaN
# loan_status                                                                           Current                       ...                                                                     NaN
# pymnt_plan                                                                                  n                       ...                                                                     NaN
# url                                         https://lendingclub.com/browse/loanDetail.acti...                       ...                                                                     NaN
# desc                                                                                      NaN                       ...                                                                     NaN
# purpose                                                                    debt_consolidation                       ...                                                                     NaN
# title                                                                                     NaN                       ...                                                                     NaN
# zip_code                                                                                907xx                       ...                                                                     NaN
# addr_state                                                                                 CA                       ...                                                                     NaN
# dti                                                                                     12.75                       ...                                                                     NaN
# delinq_2yrs                                                                                 7                       ...                                                                     NaN
# earliest_cr_line                                                                     Feb-1995                       ...                                                                     NaN
# fico_range_low                                                                            705                       ...                                                                     NaN
# fico_range_high                                                                           709                       ...                                                                     NaN
# inq_last_6mths                                                                              1                       ...                                                                     NaN
# mths_since_last_delinq                                                                      9                       ...                                                                     NaN
# mths_since_last_record                                                                    NaN                       ...                                                                     NaN
# open_acc                                                                                    5                       ...                                                                     NaN
# pub_rec                                                                                     0                       ...                                                                     NaN
# revol_bal                                                                                8633                       ...                                                                     NaN
# revol_util                                                                               64.9                       ...                                                                     NaN
# total_acc                                                                                  37                       ...                                                                     NaN
# initial_list_status                                                                         f                       ...                                                                     NaN
# out_prncp                                                                             23252.6                       ...                                                                     NaN
# out_prncp_inv                                                                         23252.6                       ...                                                                     NaN
# total_pymnt                                                                           24903.9                       ...                                                                     NaN
# total_pymnt_inv                                                                       24903.9                       ...                                                                     NaN
# total_rec_prncp                                                                       16747.4                       ...                                                                     NaN
# total_rec_int                                                                         8156.52                       ...                                                                     NaN
# total_rec_late_fee                                                                          0                       ...                                                                     NaN
# recoveries                                                                                  0                       ...                                                                     NaN
# collection_recovery_fee                                                                     0                       ...                                                                     NaN
# last_pymnt_d                                                                         Mar-2019                       ...                                                                     NaN
# last_pymnt_amnt                                                                        859.56                       ...                                                                     NaN
# next_pymnt_d                                                                         Apr-2019                       ...                                                                     NaN
# last_credit_pull_d                                                                   Mar-2019                       ...                                                                     NaN
# last_fico_range_high                                                                      724                       ...                                                                     NaN
# last_fico_range_low                                                                       720                       ...                                                                     NaN
# collections_12_mths_ex_med                                                                  0                       ...                                                                     NaN
# mths_since_last_major_derog                                                                10                       ...                                                                     NaN
# policy_code                                                                                 1                       ...                                                                     NaN
# application_type                                                                   Individual                       ...                                                                     NaN
# annual_inc_joint                                                                          NaN                       ...                                                                     NaN
# dti_joint                                                                                 NaN                       ...                                                                     NaN
# verification_status_joint                                                                 NaN                       ...                                                                     NaN
# acc_now_delinq                                                                              0                       ...                                                                     NaN
# tot_coll_amt                                                                                0                       ...                                                                     NaN
# tot_cur_bal                                                                             28398                       ...                                                                     NaN
# open_acc_6m                                                                                 0                       ...                                                                     NaN
# open_act_il                                                                                 2                       ...                                                                     NaN
# open_il_12m                                                                                 0                       ...                                                                     NaN
# open_il_24m                                                                                 1                       ...                                                                     NaN
# mths_since_rcnt_il                                                                         15                       ...                                                                     NaN
# total_bal_il                                                                            19765                       ...                                                                     NaN
# il_util                                                                                    46                       ...                                                                     NaN
# open_rv_12m                                                                                 0                       ...                                                                     NaN
# open_rv_24m                                                                                 0                       ...                                                                     NaN
# max_bal_bc                                                                               5141                       ...                                                                     NaN
# all_util                                                                                   51                       ...                                                                     NaN
# total_rev_hi_lim                                                                        13300                       ...                                                                     NaN
# inq_fi                                                                                      3                       ...                                                                     NaN
# total_cu_tl                                                                                 0                       ...                                                                     NaN
# inq_last_12m                                                                                2                       ...                                                                     NaN
# acc_open_past_24mths                                                                        2                       ...                                                                     NaN
# avg_cur_bal                                                                              5680                       ...                                                                     NaN
# bc_open_to_buy                                                                           4070                       ...                                                                     NaN
# bc_util                                                                                  66.9                       ...                                                                     NaN
# chargeoff_within_12_mths                                                                    0                       ...                                                                     NaN
# delinq_amnt                                                                                 0                       ...                                                                     NaN
# mo_sin_old_il_acct                                                                        154                       ...                                                                     NaN
# mo_sin_old_rev_tl_op                                                                      258                       ...                                                                     NaN
# mo_sin_rcnt_rev_tl_op                                                                      33                       ...                                                                     NaN
# mo_sin_rcnt_tl                                                                             15                       ...                                                                     NaN
# mort_acc                                                                                    3                       ...                                                                     NaN
# mths_since_recent_bc                                                                       41                       ...                                                                     NaN
# mths_since_recent_bc_dlq                                                                    9                       ...                                                                     NaN
# mths_since_recent_inq                                                                       1                       ...                                                                     NaN
# mths_since_recent_revol_delinq                                                              9                       ...                                                                     NaN
# num_accts_ever_120_pd                                                                       6                       ...                                                                     NaN
# num_actv_bc_tl                                                                              2                       ...                                                                     NaN
# num_actv_rev_tl                                                                             3                       ...                                                                     NaN
# num_bc_sats                                                                                 2                       ...                                                                     NaN
# num_bc_tl                                                                                  15                       ...                                                                     NaN
# num_il_tl                                                                                   9                       ...                                                                     NaN
# num_op_rev_tl                                                                               3                       ...                                                                     NaN
# num_rev_accts                                                                              23                       ...                                                                     NaN
# num_rev_tl_bal_gt_0                                                                         3                       ...                                                                     NaN
# num_sats                                                                                    5                       ...                                                                     NaN
# num_tl_120dpd_2m                                                                            0                       ...                                                                     NaN
# num_tl_30dpd                                                                                0                       ...                                                                     NaN
# num_tl_90g_dpd_24m                                                                          7                       ...                                                                     NaN
# num_tl_op_past_12m                                                                          0                       ...                                                                     NaN
# pct_tl_nvr_dlq                                                                           75.7                       ...                                                                     NaN
# percent_bc_gt_75                                                                           50                       ...                                                                     NaN
# pub_rec_bankruptcies                                                                        0                       ...                                                                     NaN
# tax_liens                                                                                   0                       ...                                                                     NaN
# tot_hi_cred_lim                                                                         55970                       ...                                                                     NaN
# total_bal_ex_mort                                                                       28398                       ...                                                                     NaN
# total_bc_limit                                                                          12300                       ...                                                                     NaN
# total_il_high_credit_limit                                                              42670                       ...                                                                     NaN
# revol_bal_joint                                                                           NaN                       ...                                                                     NaN
# sec_app_fico_range_low                                                                    NaN                       ...                                                                     NaN
# sec_app_fico_range_high                                                                   NaN                       ...                                                                     NaN
# sec_app_earliest_cr_line                                                                  NaN                       ...                                                                     NaN
# sec_app_inq_last_6mths                                                                    NaN                       ...                                                                     NaN
# sec_app_mort_acc                                                                          NaN                       ...                                                                     NaN
# sec_app_open_acc                                                                          NaN                       ...                                                                     NaN
# sec_app_revol_util                                                                        NaN                       ...                                                                     NaN
# sec_app_open_act_il                                                                       NaN                       ...                                                                     NaN
# sec_app_num_rev_accts                                                                     NaN                       ...                                                                     NaN
# sec_app_chargeoff_within_12_mths                                                          NaN                       ...                                                                     NaN
# sec_app_collections_12_mths_ex_med                                                        NaN                       ...                                                                     NaN
# sec_app_mths_since_last_major_derog                                                       NaN                       ...                                                                     NaN
# hardship_flag                                                                               N                       ...                                                                     NaN
# hardship_type                                                                             NaN                       ...                                                                     NaN
# hardship_reason                                                                           NaN                       ...                                                                     NaN
# hardship_status                                                                           NaN                       ...                                                                     NaN
# deferral_term                                                                             NaN                       ...                                                                     NaN
# hardship_amount                                                                           NaN                       ...                                                                     NaN
# hardship_start_date                                                                       NaN                       ...                                                                     NaN
# hardship_end_date                                                                         NaN                       ...                                                                     NaN
# payment_plan_start_date                                                                   NaN                       ...                                                                     NaN
# hardship_length                                                                           NaN                       ...                                                                     NaN
# hardship_dpd                                                                              NaN                       ...                                                                     NaN
# hardship_loan_status                                                                      NaN                       ...                                                                     NaN
# orig_projected_additional_accrued_interest                                                NaN                       ...                                                                     NaN
# hardship_payoff_balance_amount                                                            NaN                       ...                                                                     NaN
# hardship_last_payment_amount                                                              NaN                       ...                                                                     NaN
# disbursement_method                                                                      Cash                       ...                                                                     NaN
# debt_settlement_flag                                                                        N                       ...                                                                     NaN
# debt_settlement_flag_date                                                                 NaN                       ...                                                                     NaN
# settlement_status                                                                         NaN                       ...                                                                     NaN
# settlement_date                                                                           NaN                       ...                                                                     NaN
# settlement_amount                                                                         NaN                       ...                                                                     NaN
# settlement_percentage                                                                     NaN                       ...                                                                     NaN
# settlement_term                                                                           NaN                       ...                                                                     NaN
#
# [151 rows x 5 columns]

# %%
# .info() tells us the datatype(int64, `object` is a string)
# and will also tell us the number of non-null (not missing) data points for each column
# because this dataframe is so large, we have to force it to show the datatypes and non-null numbers with the arguments
acc_df.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2260701 entries, 0 to 2260700
# Data columns (total 151 columns):
# id                                            2260701 non-null object
# member_id                                     0 non-null float64
# loan_amnt                                     2260668 non-null float64
# funded_amnt                                   2260668 non-null float64
# funded_amnt_inv                               2260668 non-null float64
# term                                          2260668 non-null object
# int_rate                                      2260668 non-null float64
# installment                                   2260668 non-null float64
# grade                                         2260668 non-null object
# sub_grade                                     2260668 non-null object
# emp_title                                     2093699 non-null object
# emp_length                                    2113761 non-null object
# home_ownership                                2260668 non-null object
# annual_inc                                    2260664 non-null float64
# verification_status                           2260668 non-null object
# issue_d                                       2260668 non-null object
# loan_status                                   2260668 non-null object
# pymnt_plan                                    2260668 non-null object
# url                                           2260668 non-null object
# desc                                          126067 non-null object
# purpose                                       2260668 non-null object
# title                                         2237343 non-null object
# zip_code                                      2260667 non-null object
# addr_state                                    2260668 non-null object
# dti                                           2258957 non-null float64
# delinq_2yrs                                   2260639 non-null float64
# earliest_cr_line                              2260639 non-null object
# fico_range_low                                2260668 non-null float64
# fico_range_high                               2260668 non-null float64
# inq_last_6mths                                2260638 non-null float64
# mths_since_last_delinq                        1102166 non-null float64
# mths_since_last_record                        359156 non-null float64
# open_acc                                      2260639 non-null float64
# pub_rec                                       2260639 non-null float64
# revol_bal                                     2260668 non-null float64
# revol_util                                    2258866 non-null float64
# total_acc                                     2260639 non-null float64
# initial_list_status                           2260668 non-null object
# out_prncp                                     2260668 non-null float64
# out_prncp_inv                                 2260668 non-null float64
# total_pymnt                                   2260668 non-null float64
# total_pymnt_inv                               2260668 non-null float64
# total_rec_prncp                               2260668 non-null float64
# total_rec_int                                 2260668 non-null float64
# total_rec_late_fee                            2260668 non-null float64
# recoveries                                    2260668 non-null float64
# collection_recovery_fee                       2260668 non-null float64
# last_pymnt_d                                  2258241 non-null object
# last_pymnt_amnt                               2260668 non-null float64
# next_pymnt_d                                  915358 non-null object
# last_credit_pull_d                            2260596 non-null object
# last_fico_range_high                          2260668 non-null float64
# last_fico_range_low                           2260668 non-null float64
# collections_12_mths_ex_med                    2260523 non-null float64
# mths_since_last_major_derog                   580775 non-null float64
# policy_code                                   2260668 non-null float64
# application_type                              2260668 non-null object
# annual_inc_joint                              120710 non-null float64
# dti_joint                                     120706 non-null float64
# verification_status_joint                     115730 non-null object
# acc_now_delinq                                2260639 non-null float64
# tot_coll_amt                                  2190392 non-null float64
# tot_cur_bal                                   2190392 non-null float64
# open_acc_6m                                   1394538 non-null float64
# open_act_il                                   1394539 non-null float64
# open_il_12m                                   1394539 non-null float64
# open_il_24m                                   1394539 non-null float64
# mths_since_rcnt_il                            1350744 non-null float64
# total_bal_il                                  1394539 non-null float64
# il_util                                       1191818 non-null float64
# open_rv_12m                                   1394539 non-null float64
# open_rv_24m                                   1394539 non-null float64
# max_bal_bc                                    1394539 non-null float64
# all_util                                      1394320 non-null float64
# total_rev_hi_lim                              2190392 non-null float64
# inq_fi                                        1394539 non-null float64
# total_cu_tl                                   1394538 non-null float64
# inq_last_12m                                  1394538 non-null float64
# acc_open_past_24mths                          2210638 non-null float64
# avg_cur_bal                                   2190322 non-null float64
# bc_open_to_buy                                2185733 non-null float64
# bc_util                                       2184597 non-null float64
# chargeoff_within_12_mths                      2260523 non-null float64
# delinq_amnt                                   2260639 non-null float64
# mo_sin_old_il_acct                            2121597 non-null float64
# mo_sin_old_rev_tl_op                          2190391 non-null float64
# mo_sin_rcnt_rev_tl_op                         2190391 non-null float64
# mo_sin_rcnt_tl                                2190392 non-null float64
# mort_acc                                      2210638 non-null float64
# mths_since_recent_bc                          2187256 non-null float64
# mths_since_recent_bc_dlq                      519701 non-null float64
# mths_since_recent_inq                         1965233 non-null float64
# mths_since_recent_revol_delinq                740359 non-null float64
# num_accts_ever_120_pd                         2190392 non-null float64
# num_actv_bc_tl                                2190392 non-null float64
# num_actv_rev_tl                               2190392 non-null float64
# num_bc_sats                                   2202078 non-null float64
# num_bc_tl                                     2190392 non-null float64
# num_il_tl                                     2190392 non-null float64
# num_op_rev_tl                                 2190392 non-null float64
# num_rev_accts                                 2190391 non-null float64
# num_rev_tl_bal_gt_0                           2190392 non-null float64
# num_sats                                      2202078 non-null float64
# num_tl_120dpd_2m                              2107011 non-null float64
# num_tl_30dpd                                  2190392 non-null float64
# num_tl_90g_dpd_24m                            2190392 non-null float64
# num_tl_op_past_12m                            2190392 non-null float64
# pct_tl_nvr_dlq                                2190237 non-null float64
# percent_bc_gt_75                              2185289 non-null float64
# pub_rec_bankruptcies                          2259303 non-null float64
# tax_liens                                     2260563 non-null float64
# tot_hi_cred_lim                               2190392 non-null float64
# total_bal_ex_mort                             2210638 non-null float64
# total_bc_limit                                2210638 non-null float64
# total_il_high_credit_limit                    2190392 non-null float64
# revol_bal_joint                               108020 non-null float64
# sec_app_fico_range_low                        108021 non-null float64
# sec_app_fico_range_high                       108021 non-null float64
# sec_app_earliest_cr_line                      108021 non-null object
# sec_app_inq_last_6mths                        108021 non-null float64
# sec_app_mort_acc                              108021 non-null float64
# sec_app_open_acc                              108021 non-null float64
# sec_app_revol_util                            106184 non-null float64
# sec_app_open_act_il                           108021 non-null float64
# sec_app_num_rev_accts                         108021 non-null float64
# sec_app_chargeoff_within_12_mths              108021 non-null float64
# sec_app_collections_12_mths_ex_med            108021 non-null float64
# sec_app_mths_since_last_major_derog           35942 non-null float64
# hardship_flag                                 2260668 non-null object
# hardship_type                                 10917 non-null object
# hardship_reason                               10917 non-null object
# hardship_status                               10917 non-null object
# deferral_term                                 10917 non-null float64
# hardship_amount                               10917 non-null float64
# hardship_start_date                           10917 non-null object
# hardship_end_date                             10917 non-null object
# payment_plan_start_date                       10917 non-null object
# hardship_length                               10917 non-null float64
# hardship_dpd                                  10917 non-null float64
# hardship_loan_status                          10917 non-null object
# orig_projected_additional_accrued_interest    8651 non-null float64
# hardship_payoff_balance_amount                10917 non-null float64
# hardship_last_payment_amount                  10917 non-null float64
# disbursement_method                           2260668 non-null object
# debt_settlement_flag                          2260668 non-null object
# debt_settlement_flag_date                     34246 non-null object
# settlement_status                             34246 non-null object
# settlement_date                               34246 non-null object
# settlement_amount                             34246 non-null float64
# settlement_percentage                         34246 non-null float64
# settlement_term                               34246 non-null float64
# dtypes: float64(113), object(38)
# memory usage: 2.5+ GB

# %% [markdown]
# # Some common pandas functions
#
# We find ourselves doing the same types of things often in pandas.  For example, masking.
#
# ## Masking dataframes
#
# Maybe we only want to see one column.  We do this like
#
# `acc_df['int_rate']`
#
# We can also subset a dataframe based on some critereon.  Let's look at only the highest interest rates
#
# `acc_df[acc_df['int_rate'] > 20]`
#
# We can take the mean, median, get the standard deviation of columns:
#
# `acc_df['int_rate'].mean()`

# %%
# shows some common summary statistics
# again, transposing with .T to make it easier to read
acc_df.describe().T
# Out:
#                                                 count      ...                max
# member_id                                         0.0      ...                NaN
# loan_amnt                                   2260668.0      ...       4.000000e+04
# funded_amnt                                 2260668.0      ...       4.000000e+04
# funded_amnt_inv                             2260668.0      ...       4.000000e+04
# int_rate                                    2260668.0      ...       3.099000e+01
# installment                                 2260668.0      ...       1.719830e+03
# annual_inc                                  2260664.0      ...       1.100000e+08
# dti                                         2258957.0      ...       9.990000e+02
# delinq_2yrs                                 2260639.0      ...       5.800000e+01
# fico_range_low                              2260668.0      ...       8.450000e+02
# fico_range_high                             2260668.0      ...       8.500000e+02
# inq_last_6mths                              2260638.0      ...       3.300000e+01
# mths_since_last_delinq                      1102166.0      ...       2.260000e+02
# mths_since_last_record                       359156.0      ...       1.290000e+02
# open_acc                                    2260639.0      ...       1.010000e+02
# pub_rec                                     2260639.0      ...       8.600000e+01
# revol_bal                                   2260668.0      ...       2.904836e+06
# revol_util                                  2258866.0      ...       8.923000e+02
# total_acc                                   2260639.0      ...       1.760000e+02
# out_prncp                                   2260668.0      ...       4.000000e+04
# out_prncp_inv                               2260668.0      ...       4.000000e+04
# total_pymnt                                 2260668.0      ...       6.329688e+04
# total_pymnt_inv                             2260668.0      ...       6.329688e+04
# total_rec_prncp                             2260668.0      ...       4.000000e+04
# total_rec_int                               2260668.0      ...       2.819250e+04
# total_rec_late_fee                          2260668.0      ...       1.484340e+03
# recoveries                                  2260668.0      ...       3.985955e+04
# collection_recovery_fee                     2260668.0      ...       7.174719e+03
# last_pymnt_amnt                             2260668.0      ...       4.219205e+04
# last_fico_range_high                        2260668.0      ...       8.500000e+02
# last_fico_range_low                         2260668.0      ...       8.450000e+02
# collections_12_mths_ex_med                  2260523.0      ...       2.000000e+01
# mths_since_last_major_derog                  580775.0      ...       2.260000e+02
# policy_code                                 2260668.0      ...       1.000000e+00
# annual_inc_joint                             120710.0      ...       7.874821e+06
# dti_joint                                    120706.0      ...       6.949000e+01
# acc_now_delinq                              2260639.0      ...       1.400000e+01
# tot_coll_amt                                2190392.0      ...       9.152545e+06
# tot_cur_bal                                 2190392.0      ...       9.971659e+06
# open_acc_6m                                 1394538.0      ...       1.800000e+01
# open_act_il                                 1394539.0      ...       5.700000e+01
# open_il_12m                                 1394539.0      ...       2.500000e+01
# open_il_24m                                 1394539.0      ...       5.100000e+01
# mths_since_rcnt_il                          1350744.0      ...       5.110000e+02
# total_bal_il                                1394539.0      ...       1.837038e+06
# il_util                                     1191818.0      ...       1.000000e+03
# open_rv_12m                                 1394539.0      ...       2.800000e+01
# open_rv_24m                                 1394539.0      ...       6.000000e+01
# max_bal_bc                                  1394539.0      ...       1.170668e+06
# all_util                                    1394320.0      ...       2.390000e+02
# total_rev_hi_lim                            2190392.0      ...       9.999999e+06
# inq_fi                                      1394539.0      ...       4.800000e+01
# total_cu_tl                                 1394538.0      ...       1.110000e+02
# inq_last_12m                                1394538.0      ...       6.700000e+01
# acc_open_past_24mths                        2210638.0      ...       6.400000e+01
# avg_cur_bal                                 2190322.0      ...       9.580840e+05
# bc_open_to_buy                              2185733.0      ...       7.111400e+05
# bc_util                                     2184597.0      ...       3.396000e+02
# chargeoff_within_12_mths                    2260523.0      ...       1.000000e+01
# delinq_amnt                                 2260639.0      ...       2.499250e+05
# mo_sin_old_il_acct                          2121597.0      ...       9.990000e+02
# mo_sin_old_rev_tl_op                        2190391.0      ...       9.990000e+02
# mo_sin_rcnt_rev_tl_op                       2190391.0      ...       5.470000e+02
# mo_sin_rcnt_tl                              2190392.0      ...       3.820000e+02
# mort_acc                                    2210638.0      ...       9.400000e+01
# mths_since_recent_bc                        2187256.0      ...       6.610000e+02
# mths_since_recent_bc_dlq                     519701.0      ...       2.020000e+02
# mths_since_recent_inq                       1965233.0      ...       2.500000e+01
# mths_since_recent_revol_delinq               740359.0      ...       2.020000e+02
# num_accts_ever_120_pd                       2190392.0      ...       5.800000e+01
# num_actv_bc_tl                              2190392.0      ...       5.000000e+01
# num_actv_rev_tl                             2190392.0      ...       7.200000e+01
# num_bc_sats                                 2202078.0      ...       7.100000e+01
# num_bc_tl                                   2190392.0      ...       8.600000e+01
# num_il_tl                                   2190392.0      ...       1.590000e+02
# num_op_rev_tl                               2190392.0      ...       9.100000e+01
# num_rev_accts                               2190391.0      ...       1.510000e+02
# num_rev_tl_bal_gt_0                         2190392.0      ...       6.500000e+01
# num_sats                                    2202078.0      ...       1.010000e+02
# num_tl_120dpd_2m                            2107011.0      ...       7.000000e+00
# num_tl_30dpd                                2190392.0      ...       4.000000e+00
# num_tl_90g_dpd_24m                          2190392.0      ...       5.800000e+01
# num_tl_op_past_12m                          2190392.0      ...       3.200000e+01
# pct_tl_nvr_dlq                              2190237.0      ...       1.000000e+02
# percent_bc_gt_75                            2185289.0      ...       1.000000e+02
# pub_rec_bankruptcies                        2259303.0      ...       1.200000e+01
# tax_liens                                   2260563.0      ...       8.500000e+01
# tot_hi_cred_lim                             2190392.0      ...       9.999999e+06
# total_bal_ex_mort                           2210638.0      ...       3.408095e+06
# total_bc_limit                              2210638.0      ...       1.569000e+06
# total_il_high_credit_limit                  2190392.0      ...       2.118996e+06
# revol_bal_joint                              108020.0      ...       1.110019e+06
# sec_app_fico_range_low                       108021.0      ...       8.450000e+02
# sec_app_fico_range_high                      108021.0      ...       8.500000e+02
# sec_app_inq_last_6mths                       108021.0      ...       6.000000e+00
# sec_app_mort_acc                             108021.0      ...       2.700000e+01
# sec_app_open_acc                             108021.0      ...       8.200000e+01
# sec_app_revol_util                           106184.0      ...       4.343000e+02
# sec_app_open_act_il                          108021.0      ...       4.300000e+01
# sec_app_num_rev_accts                        108021.0      ...       1.060000e+02
# sec_app_chargeoff_within_12_mths             108021.0      ...       2.100000e+01
# sec_app_collections_12_mths_ex_med           108021.0      ...       2.300000e+01
# sec_app_mths_since_last_major_derog           35942.0      ...       1.850000e+02
# deferral_term                                 10917.0      ...       3.000000e+00
# hardship_amount                               10917.0      ...       9.439400e+02
# hardship_length                               10917.0      ...       3.000000e+00
# hardship_dpd                                  10917.0      ...       3.700000e+01
# orig_projected_additional_accrued_interest     8651.0      ...       2.680890e+03
# hardship_payoff_balance_amount                10917.0      ...       4.030641e+04
# hardship_last_payment_amount                  10917.0      ...       1.407860e+03
# settlement_amount                             34246.0      ...       3.360100e+04
# settlement_percentage                         34246.0      ...       5.213500e+02
# settlement_term                               34246.0      ...       1.810000e+02
#
# [113 rows x 8 columns]

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
# "magic" command to make plots show up in the notebook
# %matplotlib inline

# %%
acc_df[acc_df['int_rate'] > 20]['int_rate'].mean()
# thats a bit of a complicated statement.  Breaking it down:
# acc_df['int_rate'] > 20 returns a mask: an array of True/False values
# putting this array into acc_df[] returns the dataframe rows where the interest rates are greater than 20

# so this first part: acc_df[acc_df['int_rate'] > 20]
# gives us a dataframe

# we select a column with ['int_rate'] at the end.  Then we get the average value with .mean()
# Out:
# 23.781285536770067

# %% [markdown]
# ## Finding unique values
#
# Numpy has a function for finding the unique values in an array:
#
# np.unique(array)
#
# This is built into pandas:
#
# acc_df['grade'].unique()
#
# shows us the unique values in that column.

# %%
acc_df['grade'].unique()
# Out:
# array(['C', 'B', 'F', 'A', 'E', 'D', 'G', nan], dtype=object)

# %%
# selecting only grade A loans:
acc_df[acc_df['grade'] == 'A'].describe().T
# Out:
#                                                count      ...                max
# member_id                                        0.0      ...                NaN
# loan_amnt                                   433027.0      ...       4.000000e+04
# funded_amnt                                 433027.0      ...       4.000000e+04
# funded_amnt_inv                             433027.0      ...       4.000000e+04
# int_rate                                    433027.0      ...       9.630000e+00
# installment                                 433027.0      ...       1.268460e+03
# annual_inc                                  433023.0      ...       9.573072e+06
# dti                                         432738.0      ...       9.990000e+02
# delinq_2yrs                                 433016.0      ...       5.800000e+01
# fico_range_low                              433027.0      ...       8.450000e+02
# fico_range_high                             433027.0      ...       8.500000e+02
# inq_last_6mths                              433016.0      ...       1.000000e+01
# mths_since_last_delinq                      163626.0      ...       1.790000e+02
# mths_since_last_record                       38836.0      ...       1.260000e+02
# open_acc                                    433016.0      ...       9.300000e+01
# pub_rec                                     433016.0      ...       3.700000e+01
# revol_bal                                   433027.0      ...       2.568995e+06
# revol_util                                  432832.0      ...       1.720000e+02
# total_acc                                   433016.0      ...       1.510000e+02
# out_prncp                                   433027.0      ...       3.899009e+04
# out_prncp_inv                               433027.0      ...       3.899009e+04
# total_pymnt                                 433027.0      ...       4.681351e+04
# total_pymnt_inv                             433027.0      ...       4.681351e+04
# total_rec_prncp                             433027.0      ...       4.000000e+04
# total_rec_int                               433027.0      ...       7.010910e+03
# total_rec_late_fee                          433027.0      ...       1.188830e+03
# recoveries                                  433027.0      ...       2.377978e+04
# collection_recovery_fee                     433027.0      ...       5.774800e+03
# last_pymnt_amnt                             433027.0      ...       4.139944e+04
# last_fico_range_high                        433027.0      ...       8.500000e+02
# last_fico_range_low                         433027.0      ...       8.450000e+02
# collections_12_mths_ex_med                  432992.0      ...       2.000000e+01
# mths_since_last_major_derog                  70653.0      ...       1.790000e+02
# policy_code                                 433027.0      ...       1.000000e+00
# annual_inc_joint                             22353.0      ...       1.950000e+06
# dti_joint                                    22353.0      ...       4.478000e+01
# acc_now_delinq                              433016.0      ...       4.000000e+00
# tot_coll_amt                                416281.0      ...       2.241070e+05
# tot_cur_bal                                 416281.0      ...       8.524709e+06
# open_acc_6m                                 288518.0      ...       1.200000e+01
# open_act_il                                 288518.0      ...       4.900000e+01
# open_il_12m                                 288518.0      ...       1.100000e+01
# open_il_24m                                 288518.0      ...       2.000000e+01
# mths_since_rcnt_il                          281165.0      ...       5.030000e+02
# total_bal_il                                288518.0      ...       1.044916e+06
# il_util                                     241202.0      ...       1.000000e+03
# open_rv_12m                                 288518.0      ...       1.800000e+01
# open_rv_24m                                 288518.0      ...       3.800000e+01
# max_bal_bc                                  288518.0      ...       4.575210e+05
# all_util                                    288495.0      ...       1.880000e+02
# total_rev_hi_lim                            416281.0      ...       9.999999e+06
# inq_fi                                      288518.0      ...       1.900000e+01
# total_cu_tl                                 288518.0      ...       6.800000e+01
# inq_last_12m                                288518.0      ...       3.400000e+01
# acc_open_past_24mths                        420666.0      ...       3.900000e+01
# avg_cur_bal                                 416279.0      ...       7.103920e+05
# bc_open_to_buy                              418033.0      ...       5.072590e+05
# bc_util                                     417806.0      ...       2.157000e+02
# chargeoff_within_12_mths                    432992.0      ...       7.000000e+00
# delinq_amnt                                 433016.0      ...       6.565200e+04
# mo_sin_old_il_acct                          406217.0      ...       7.240000e+02
# mo_sin_old_rev_tl_op                        416281.0      ...       9.990000e+02
# mo_sin_rcnt_rev_tl_op                       416281.0      ...       4.380000e+02
# mo_sin_rcnt_tl                              416281.0      ...       3.680000e+02
# mort_acc                                    420666.0      ...       8.700000e+01
# mths_since_recent_bc                        418239.0      ...       6.390000e+02
# mths_since_recent_bc_dlq                     71538.0      ...       1.700000e+02
# mths_since_recent_inq                       349965.0      ...       2.500000e+01
# mths_since_recent_revol_delinq              107093.0      ...       1.790000e+02
# num_accts_ever_120_pd                       416281.0      ...       5.800000e+01
# num_actv_bc_tl                              416281.0      ...       4.700000e+01
# num_actv_rev_tl                             416281.0      ...       5.900000e+01
# num_bc_sats                                 418456.0      ...       6.100000e+01
# num_bc_tl                                   416281.0      ...       7.700000e+01
# num_il_tl                                   416281.0      ...       1.300000e+02
# num_op_rev_tl                               416281.0      ...       9.100000e+01
# num_rev_accts                               416281.0      ...       1.430000e+02
# num_rev_tl_bal_gt_0                         416281.0      ...       5.900000e+01
# num_sats                                    418456.0      ...       9.300000e+01
# num_tl_120dpd_2m                            408038.0      ...       2.000000e+00
# num_tl_30dpd                                416281.0      ...       3.000000e+00
# num_tl_90g_dpd_24m                          416281.0      ...       5.800000e+01
# num_tl_op_past_12m                          416281.0      ...       2.100000e+01
# pct_tl_nvr_dlq                              416265.0      ...       1.000000e+02
# percent_bc_gt_75                            418028.0      ...       1.000000e+02
# pub_rec_bankruptcies                        432859.0      ...       8.000000e+00
# tax_liens                                   432997.0      ...       3.700000e+01
# tot_hi_cred_lim                             416281.0      ...       9.999999e+06
# total_bal_ex_mort                           420666.0      ...       2.698600e+06
# total_bc_limit                              420666.0      ...       7.600000e+05
# total_il_high_credit_limit                  416281.0      ...       2.101913e+06
# revol_bal_joint                              21195.0      ...       3.484950e+05
# sec_app_fico_range_low                       21195.0      ...       8.450000e+02
# sec_app_fico_range_high                      21195.0      ...       8.500000e+02
# sec_app_inq_last_6mths                       21195.0      ...       6.000000e+00
# sec_app_mort_acc                             21195.0      ...       2.300000e+01
# sec_app_open_acc                             21195.0      ...       8.200000e+01
# sec_app_revol_util                           20929.0      ...       1.639000e+02
# sec_app_open_act_il                          21195.0      ...       3.900000e+01
# sec_app_num_rev_accts                        21195.0      ...       9.200000e+01
# sec_app_chargeoff_within_12_mths             21195.0      ...       1.700000e+01
# sec_app_collections_12_mths_ex_med           21195.0      ...       1.500000e+01
# sec_app_mths_since_last_major_derog           5168.0      ...       1.590000e+02
# deferral_term                                  548.0      ...       3.000000e+00
# hardship_amount                                548.0      ...       2.425200e+02
# hardship_length                                548.0      ...       3.000000e+00
# hardship_dpd                                   548.0      ...       3.000000e+01
# orig_projected_additional_accrued_interest     476.0      ...       7.275600e+02
# hardship_payoff_balance_amount                 548.0      ...       4.014935e+04
# hardship_last_payment_amount                   548.0      ...       1.076010e+03
# settlement_amount                             2212.0      ...       2.228800e+04
# settlement_percentage                         2212.0      ...       9.002000e+01
# settlement_term                               2212.0      ...       3.600000e+01
#
# [113 rows x 8 columns]

# %%
acc_df['loan_status'].unique()
# Out:
# array(['Fully Paid', 'Current', 'Charged Off', 'In Grace Period',
#        'Late (31-120 days)', 'Late (16-30 days)', 'Default', nan,
#        'Does not meet the credit policy. Status:Fully Paid',
#        'Does not meet the credit policy. Status:Charged Off'],
#       dtype=object)

# %%
# looking at only defaulted loans:
default_categories = ['Default', 'Charged Off', 'Does not meet the credit policy. Status:Charged Off']
# .isin() is a trick for checking if something is in a list
# it's a pandas-specific function
acc_df[acc_df['loan_status'].isin(default_categories)].describe().T
# check out the average interest rate and dti (debt-to-income)
# Out:
#                                                count      ...                max
# member_id                                        0.0      ...                NaN
# loan_amnt                                   269360.0      ...       4.000000e+04
# funded_amnt                                 269360.0      ...       4.000000e+04
# funded_amnt_inv                             269360.0      ...       4.000000e+04
# int_rate                                    269360.0      ...       3.099000e+01
# installment                                 269360.0      ...       1.717630e+03
# annual_inc                                  269360.0      ...       9.500000e+06
# dti                                         269289.0      ...       9.990000e+02
# delinq_2yrs                                 269357.0      ...       2.700000e+01
# fico_range_low                              269360.0      ...       8.450000e+02
# fico_range_high                             269360.0      ...       8.500000e+02
# inq_last_6mths                              269357.0      ...       3.300000e+01
# mths_since_last_delinq                      138305.0      ...       2.260000e+02
# mths_since_last_record                       52268.0      ...       1.290000e+02
# open_acc                                    269357.0      ...       7.600000e+01
# pub_rec                                     269357.0      ...       8.600000e+01
# revol_bal                                   269360.0      ...       1.746716e+06
# revol_util                                  269174.0      ...       3.666000e+02
# total_acc                                   269357.0      ...       1.760000e+02
# out_prncp                                   269360.0      ...       2.822201e+04
# out_prncp_inv                               269360.0      ...       2.822201e+04
# total_pymnt                                 269360.0      ...       6.194753e+04
# total_pymnt_inv                             269360.0      ...       6.194753e+04
# total_rec_prncp                             269360.0      ...       3.998979e+04
# total_rec_int                               269360.0      ...       2.682238e+04
# total_rec_late_fee                          269360.0      ...       8.741700e+02
# recoveries                                  269360.0      ...       3.985955e+04
# collection_recovery_fee                     269360.0      ...       7.174719e+03
# last_pymnt_amnt                             269360.0      ...       3.989829e+04
# last_fico_range_high                        269360.0      ...       8.500000e+02
# last_fico_range_low                         269360.0      ...       8.450000e+02
# collections_12_mths_ex_med                  269332.0      ...       9.000000e+00
# mths_since_last_major_derog                  77624.0      ...       2.260000e+02
# policy_code                                 269360.0      ...       1.000000e+00
# annual_inc_joint                              6350.0      ...       1.837000e+06
# dti_joint                                     6350.0      ...       6.949000e+01
# acc_now_delinq                              269357.0      ...       6.000000e+00
# tot_coll_amt                                258281.0      ...       1.469170e+05
# tot_cur_bal                                 258281.0      ...       3.437283e+06
# open_acc_6m                                 120136.0      ...       1.800000e+01
# open_act_il                                 120136.0      ...       5.700000e+01
# open_il_12m                                 120136.0      ...       2.500000e+01
# open_il_24m                                 120136.0      ...       5.100000e+01
# mths_since_rcnt_il                          116354.0      ...       5.110000e+02
# total_bal_il                                120136.0      ...       7.961040e+05
# il_util                                     104930.0      ...       5.580000e+02
# open_rv_12m                                 120136.0      ...       2.600000e+01
# open_rv_24m                                 120136.0      ...       4.900000e+01
# max_bal_bc                                  120136.0      ...       2.088720e+05
# all_util                                    120127.0      ...       1.840000e+02
# total_rev_hi_lim                            258281.0      ...       1.998700e+06
# inq_fi                                      120136.0      ...       2.800000e+01
# total_cu_tl                                 120136.0      ...       5.400000e+01
# inq_last_12m                                120136.0      ...       4.000000e+01
# acc_open_past_24mths                        261713.0      ...       6.400000e+01
# avg_cur_bal                                 258274.0      ...       3.558240e+05
# bc_open_to_buy                              258767.0      ...       3.275120e+05
# bc_util                                     258600.0      ...       2.552000e+02
# chargeoff_within_12_mths                    269332.0      ...       8.000000e+00
# delinq_amnt                                 269357.0      ...       2.499250e+05
# mo_sin_old_il_acct                          250071.0      ...       7.200000e+02
# mo_sin_old_rev_tl_op                        258280.0      ...       8.420000e+02
# mo_sin_rcnt_rev_tl_op                       258280.0      ...       3.720000e+02
# mo_sin_rcnt_tl                              258281.0      ...       2.890000e+02
# mort_acc                                    261713.0      ...       2.900000e+01
# mths_since_recent_bc                        258969.0      ...       6.110000e+02
# mths_since_recent_bc_dlq                     66951.0      ...       2.020000e+02
# mths_since_recent_inq                       242697.0      ...       2.500000e+01
# mths_since_recent_revol_delinq               93057.0      ...       2.020000e+02
# num_accts_ever_120_pd                       258281.0      ...       3.400000e+01
# num_actv_bc_tl                              258281.0      ...       3.000000e+01
# num_actv_rev_tl                             258281.0      ...       4.700000e+01
# num_bc_sats                                 260335.0      ...       4.400000e+01
# num_bc_tl                                   258281.0      ...       5.700000e+01
# num_il_tl                                   258281.0      ...       1.590000e+02
# num_op_rev_tl                               258281.0      ...       7.200000e+01
# num_rev_accts                               258281.0      ...       1.010000e+02
# num_rev_tl_bal_gt_0                         258281.0      ...       4.400000e+01
# num_sats                                    260335.0      ...       7.600000e+01
# num_tl_120dpd_2m                            244675.0      ...       6.000000e+00
# num_tl_30dpd                                258281.0      ...       4.000000e+00
# num_tl_90g_dpd_24m                          258281.0      ...       2.600000e+01
# num_tl_op_past_12m                          258281.0      ...       3.200000e+01
# pct_tl_nvr_dlq                              258259.0      ...       1.000000e+02
# percent_bc_gt_75                            258689.0      ...       1.000000e+02
# pub_rec_bankruptcies                        269026.0      ...       1.100000e+01
# tax_liens                                   269349.0      ...       8.500000e+01
# tot_hi_cred_lim                             258281.0      ...       9.999999e+06
# total_bal_ex_mort                           261713.0      ...       1.896461e+06
# total_bc_limit                              261713.0      ...       5.608000e+05
# total_il_high_credit_limit                  258281.0      ...       9.545030e+05
# revol_bal_joint                               4621.0      ...       2.664160e+05
# sec_app_fico_range_low                        4621.0      ...       8.050000e+02
# sec_app_fico_range_high                       4621.0      ...       8.090000e+02
# sec_app_inq_last_6mths                        4621.0      ...       6.000000e+00
# sec_app_mort_acc                              4621.0      ...       1.300000e+01
# sec_app_open_acc                              4621.0      ...       5.400000e+01
# sec_app_revol_util                            4481.0      ...       2.126000e+02
# sec_app_open_act_il                           4621.0      ...       3.800000e+01
# sec_app_num_rev_accts                         4621.0      ...       6.200000e+01
# sec_app_chargeoff_within_12_mths              4621.0      ...       2.000000e+01
# sec_app_collections_12_mths_ex_med            4621.0      ...       1.100000e+01
# sec_app_mths_since_last_major_derog           2020.0      ...       1.150000e+02
# deferral_term                                 4062.0      ...       3.000000e+00
# hardship_amount                               4062.0      ...       9.439400e+02
# hardship_length                               4062.0      ...       3.000000e+00
# hardship_dpd                                  4062.0      ...       3.200000e+01
# orig_projected_additional_accrued_interest    2159.0      ...       2.267280e+03
# hardship_payoff_balance_amount                4062.0      ...       3.839900e+04
# hardship_last_payment_amount                  4062.0      ...       1.407860e+03
# settlement_amount                            33287.0      ...       3.360100e+04
# settlement_percentage                        33287.0      ...       5.213500e+02
# settlement_term                              33287.0      ...       1.810000e+02
#
# [113 rows x 8 columns]

# %%
# Seaborn is a recently-created Python library for easily making nice-looking plots
# You will have to install it with `conda install seaborn` or `pip install seaborn`, etc

# The docs are here for this function: http://seaborn.pydata.org/generated/seaborn.distplot.html
# Found by Googling 'seaborn histogram'
# Need to drop missing values, otherwise throws an error
# It would be better to impute missing values.
f = sns.distplot(acc_df['dti'].dropna())
# Out:
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# outliers are screwing up the histogram... remove them
# adapted from http://stackoverflow.com/questions/11686720/is-there-a-numpy-builtin-to-reject-outliers-from-a-list
# we're using interquartile range to determine outliers
def reject_outliers(sr, iq_range=0.5, side='left', return_mask=False):
    """
    Takes an array (or pandas series) and returns an array with outliers excluded, according to the
    interquartile range.
    
    Parameters:
    -----------
    sr: array
        array of numeric values
    iq_range: float
        percent to calculate quartiles by, 0.5 will yield 25% and 75%ile quartiles
    side: string
        if 'left', will return everything below the highest quartile
        if 'right', will return everything above the lowest quartile
        if 'both', will return everything between the high and low quartiles
    """
    pcnt = (1 - iq_range) / 2
    qlow, median, qhigh = sr.dropna().quantile([pcnt, 0.50, 1-pcnt])
    iqr = qhigh - qlow
    if side=='both':
        mask = (sr - median).abs() <= iqr
    elif side=='left':
        mask = (sr - median) <= iqr
    elif side=='right':
        mask = (sr - median) >= iqr
    else:
        print('options for side are left, right, or both')
    
    if return_mask:
        return mask
    
    return sr[mask]

# %%
# sweeeeeeeetttt....
dti_no_outliers = reject_outliers(acc_df['dti'], iq_range=0.85) # arrived at 0.85 via trial and error
f = sns.distplot(dti_no_outliers)
# other types of plot examples:
# http://seaborn.pydata.org/examples/
# Out:
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# sets the xkcd style if you want to make the plots look funny...may neet to install some fonts
plt.xkcd()

# %%
f = sns.distplot(dti_no_outliers)
# Out:
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /opt/conda/lib/python3.6/site-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['xkcd', 'xkcd Script', 'Humor Sans', 'Comic Sans MS'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# back to default
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

# %%
f = sns.distplot(dti_no_outliers)
# Out:
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# other styles:
# http://matplotlib.org/users/style_sheets.html
# this is the R ggplot style, which some people really like
plt.style.use('ggplot')

# %%
# http://seaborn.pydata.org/generated/seaborn.regplot.html
# takes a long time because there are a lot of points, but works for smaller datasets
# f = sns.regplot(data=acc_df, x='dti', y='int_rate', fit_reg=False)
# instead, lets make a heatmap:
# http://stackoverflow.com/questions/2369492/generate-a-heatmap-in-matplotlib-using-a-scatter-data-set
# http://seaborn.pydata.org/generated/seaborn.jointplot.html
mask = reject_outliers(acc_df['dti'], iq_range=0.85, return_mask=True)
f = sns.jointplot(data=acc_df.ix[mask, :], x='dti', y='int_rate', kind='hex', joint_kws=dict(gridsize=50))
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:8: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#
# /opt/conda/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
