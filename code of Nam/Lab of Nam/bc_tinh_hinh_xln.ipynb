# %% [markdown]
# ## 30/04/2023

# %%
import pandas as pd
# from unidecode import unidecode
from datetime import date
from sqlalchemy import create_engine
conn = create_engine('postgresql+psycopg2://postgres:Baohoai123%40@192.168.1.123/cbquant')
df = pd.read_excel('./xln_file/2023-04-30_B.CN_TINH HINH XU LY NHOM NHO LE - 30042023.xlsx',
                   sheet_name='CHI TIET TINH HINH XU LY', 
                   skiprows=3)
df = df[2:].reset_index(drop=True)
# df = df.drop(['Phòng Giao Dịch'], axis=1)
# df = df.dropna(subset=['CIF'])[1:].reset_index(drop=True)
df.columns = ['cif',
            'chi_nhanh', 
            'ten_khach_hang',
            'tinh_chat', 
            'no_cu_no_moi',
            'no_nq42',
            'nhom_no',
            'du_no',
            'gia_tri_tsbd_ho_so_vay',
            'gia_tri_tsbd_dinh_gia_gan_nhat',
            'tinh_chat_ho_so_vay_theo_tsbd',
            'bien_phap_xu_ly',
            'tinh_trang_to_tung',
            'nguyen_nhan_qua_han',
            'qua_trinh_xu_ly',
            'tong_quan_tinh_hinh_xu_ly',
            'kho_khan_vuong_mac',
            'kien_nghi',
            'phan_nhom_mau_sac',
            'kha_thu_goc',
            'kha_thu_lai',
            'mat_goc',
            'ty_le_kha_thu_goc_du_no_goc',
            'yeu_to_lam_cham',
            'tinh_trang_ho_so',
            'ten_cbpt',
            'nam_phat_sinh_no_xau']
df.head()
# Out:
#                 CIF      Chi nhánh    Tên khách hàng  \
# 0     DANG NGOC ANH   CN RACH KIEN     DANG NGOC ANH
# 1  PHUNG MINH LUONG   CN RACH KIEN  PHUNG MINH LUONG
# 2    NGUYEN THI HAI   CN RACH KIEN    NGUYEN THI HAI
# 3        2110000631     CN LONG AN     BUI DUY QUANG
# 4        6000047063  CN KIEN GIANG     BUI HOANG ANH
#
#   - Nội bảng;\n- VAMC;\n- Nhận lại nợ từ VAMC NỢ CŨ/NỢ MỚI           NỢ NQ42  \
# 0                                  DA SD DPRR        NO CU        THUOC NQ42
# 1                                  DA SD DPRR        NO CU        THUOC NQ42
# 2                                  DA SD DPRR        NO CU        THUOC NQ42
# 3                                    NOI BANG        NO CU        THUOC NQ42
# 4                                    NOI BANG       NO MOI  KHONG THUOC NQ42
#
#    NHÓM NỢ        DƯ NỢ  Giá trị TSBĐ hồ sơ vay  \
# 0      NaN    2499000.0                     0.0
# 1      NaN     800000.0                     0.0
# ...

# %% [markdown]
# # 31/07/2023

# %%
import pandas as pd
# from unidecode import unidecode
from datetime import date
from sqlalchemy import create_engine
conn = create_engine('postgresql+psycopg2://postgres:Baohoai123%40@192.168.1.123/cbquant')

df = pd.read_excel('./xln_file/2023-08-02_B.CN_TINH HINH XU LY NHOM NHO LE - 31072023.xlsx', sheet_name='Sheet1', skiprows=5)
df = df.drop(['Phòng Giao Dịch'], axis=1)
df = df.dropna(subset=['CIF'])[1:].reset_index(drop=True)
df.columns = ['cif', 'chi_nhanh', 'ten_khach_hang',
       'tinh_chat', 'no_cu_no_moi',
       'no_nq42', 'nhom_no', 'du_no', 'gia_tri_tsbd_ho_so_vay',
       'gia_tri_tsbd_dinh_gia_gan_nhat', 'tinh_chat_ho_so_vay_theo_tsbd',
       'bien_phap_xu_ly', 'tinh_trang_to_tung',
       'nguyen_nhan_qua_han',
       'qua_trinh_xu_ly',
       'tong_quan_tinh_hinh_xu_ly',
       'kho_khan_vuong_mac',
       'kien_nghi',
       'phan_nhom_mau_sac', 'kha_thu_goc', 'kha_thu_lai',
       'mat_goc', 'ty_le_kha_thu_goc_du_no_goc', 'yeu_to_lam_cham',
       'tinh_trang_ho_so', 'ten_cbpt', 'nam_phat_sinh_no_xau']
df.gia_tri_tsbd_dinh_gia_gan_nhat = df.gia_tri_tsbd_dinh_gia_gan_nhat.astype(str).str.replace(',','').astype(float)
df.yeu_to_lam_cham = df.yeu_to_lam_cham.map({'Y':True, 'N':False})
df['date_report'] = date(2023,7,31)
df.to_sql('tinh_hinh_xu_ly_no_nhom_nho_le',con=conn, index=False, schema='dmt', if_exists='append')
df.kha_thu_lai = df.kha_thu_lai.astype(str).apply(lambda x: float(x) if x.strip() != '-' else None)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 647 entries, 0 to 646
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   cif                             647 non-null    object
#  1   chi_nhanh                       647 non-null    object
#  2   ten_khach_hang                  647 non-null    object
#  3   tinh_chat                       647 non-null    object
#  4   no_cu_no_moi                    647 non-null    object
#  5   no_nq42                         647 non-null    object
#  6   nhom_no                         575 non-null    float64
#  7   du_no                           647 non-null    float64
#  8   gia_tri_tsbd_ho_so_vay          647 non-null    float64
#  9   gia_tri_tsbd_dinh_gia_gan_nhat  647 non-null    float64
#  10  tinh_chat_ho_so_vay_theo_tsbd   647 non-null    object
#  11  bien_phap_xu_ly                 645 non-null    object
# ...

# %% [markdown]
# # 31/08/2023

# %%
import pandas as pd
import numpy as np
from unidecode import unidecode
from datetime import date
from sqlalchemy import create_engine
conn = create_engine('postgresql+psycopg2://postgres:Baohoai123%40@192.168.1.123/cbquant')


df = pd.read_excel('/hdd_data/jupyter/Khoi/Nam_bàn_giao/xln_file/2023-09-07_B.CN_TINH HINH XU LY NHOM NHO LE - 31082023.xlsx',
                  sheet_name='Sheet1', skiprows=5)
df = df.drop(['Phòng Giao Dịch'], axis=1)
df = df.dropna(subset=['CIF'])[1:].reset_index(drop=True)
df.columns = ['cif', 
            'chi_nhanh', 
            'ten_khach_hang',
            'tinh_chat', 'no_cu_no_moi',
            'no_nq42', 'nhom_no', 'du_no', 
            'gia_tri_tsbd_ho_so_vay',
            'gia_tri_tsbd_dinh_gia_gan_nhat', 
            'tinh_chat_ho_so_vay_theo_tsbd',
            'bien_phap_xu_ly', 'tinh_trang_to_tung',
            'nguyen_nhan_qua_han',
            # 'qua_trinh_xu_ly',
            'kho_khan_vuong_mac',      
            'tong_quan_tinh_hinh_xu_ly',
            # 'kien_nghi',
            'phan_nhom_mau_sac', 
            'kha_thu_goc', 
            'kha_thu_lai',
            'mat_goc', 
            'ty_le_kha_thu_goc_du_no_goc',
            # 'yeu_to_lam_cham',
            'tinh_trang_ho_so', 
            'ten_cbpt',
            'nam_phat_sinh_no_xau']
df.gia_tri_tsbd_dinh_gia_gan_nhat = df.gia_tri_tsbd_dinh_gia_gan_nhat.astype(str).str.replace(',','').astype(float)
df['yeu_to_lam_cham'] = np.NaN
df['qua_trinh_xu_ly'] = np.NaN
df['kien_nghi'] = np.NaN
df['date_report'] = date(2023,8,31)
df.kha_thu_lai = df.kha_thu_lai.astype(str).str.replace('.','')
df.kha_thu_lai = df.kha_thu_lai.astype(str).apply(lambda x: float(x) if x.strip() != '-' else None)
display(df.info())
df.to_sql('tinh_hinh_xu_ly_no_nhom_nho_le',con=conn, index=False, schema='dmt', if_exists='append')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 676 entries, 0 to 675
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   cif                             676 non-null    object
#  1   chi_nhanh                       676 non-null    object
#  2   ten_khach_hang                  676 non-null    object
#  3   tinh_chat                       676 non-null    object
#  4   no_cu_no_moi                    676 non-null    object
#  5   no_nq42                         676 non-null    object
#  6   nhom_no                         603 non-null    float64
#  7   du_no                           676 non-null    float64
#  8   gia_tri_tsbd_ho_so_vay          676 non-null    float64
#  9   gia_tri_tsbd_dinh_gia_gan_nhat  543 non-null    float64
#  10  tinh_chat_ho_so_vay_theo_tsbd   619 non-null    object
#  11  bien_phap_xu_ly                 618 non-null    object
# ...

# %% [markdown]
# ## 30/09/2023

# %%
import pandas as pd
# from unidecode import unidecode
from datetime import date
from sqlalchemy import create_engine
conn = create_engine('postgresql+psycopg2://postgres:Baohoai123%40@192.168.1.123/cbquant')

df = pd.read_excel('./xln_file/2023-10-05_B.CN_TINH HINH XU LY NHOM NHO LE - 30092023.xlsx', sheet_name='Sheet1', skiprows=5)
df = df[2:].reset_index(drop=True)
df = df.dropna(subset=['CIF'])[1:].reset_index(drop=True)
df = df.drop(['Phòng Giao Dịch'], axis=1)
df = df.drop(['Nguyên nhân quá hạn\n(- Do SXKD thua lỗ;\n- Do khách hàng thất nghiệp;\n- Do……)',
       'Tình hình khách hàng, hồ sơ cho vay, TSBĐ…',
       'Tổng quan tình hình xử lý\n(Nêu khái quát tình hình, nổi bật kết quả đến thời điểm báo cáo)'], axis=1)
df.columns = ['cif', 
            'chi_nhanh', 
            'ten_khach_hang',
            'tinh_chat', 'no_cu_no_moi',
            'no_nq42', 'nhom_no', 'du_no', 
            'gia_tri_tsbd_ho_so_vay',
            'gia_tri_tsbd_dinh_gia_gan_nhat', 
            'tinh_chat_ho_so_vay_theo_tsbd',
             'bien_phap_xu_ly', 'tinh_trang_to_tung',
            'nguyen_nhan_qua_han',
            # 'qua_trinh_xu_ly',
            'kho_khan_vuong_mac',      
            'tong_quan_tinh_hinh_xu_ly',
            'kien_nghi',
            'phan_nhom_mau_sac', 
            'kha_thu_goc', 
            'kha_thu_lai',
            'mat_goc', 
            'ty_le_kha_thu_goc_du_no_goc',
            # 'yeu_to_lam_cham',
            'tinh_trang_ho_so', 
            'ten_cbpt',
            'nam_phat_sinh_no_xau']
df['date_report'] = date(2023,9,30)
df.gia_tri_tsbd_dinh_gia_gan_nhat = df.gia_tri_tsbd_dinh_gia_gan_nhat.astype(str).str.replace(',','')
df.gia_tri_tsbd_dinh_gia_gan_nhat = df.gia_tri_tsbd_dinh_gia_gan_nhat.astype(str).str.replace('.','')
df.kha_thu_lai = df.kha_thu_lai.astype(str).str.replace('.','')
df.gia_tri_tsbd_dinh_gia_gan_nhat = df.gia_tri_tsbd_dinh_gia_gan_nhat.astype(str).apply(lambda x: float(x) if x.strip() != '-' else None)
df.kha_thu_lai = df.kha_thu_lai.astype(str).apply(lambda x: float(x) if x.strip() != '-' else None)
display(df.info())
df.to_sql('tinh_hinh_xu_ly_no_nhom_nho_le',con=conn, index=False, schema='dmt', if_exists='append')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[151], line 14
#      10 df = df.drop(['Phòng Giao Dịch'], axis=1)
#      11 df = df.drop(['Nguyên nhân quá hạn\n(- Do SXKD thua lỗ;\n- Do khách hàng thất nghiệp;\n- Do……)',
#      12        'Tình hình khách hàng, hồ sơ cho vay, TSBĐ…',
#      13        'Tổng quan tình hình xử lý\n(Nêu khái quát tình hình, nổi bật kết quả đến thời điểm báo cáo)'], axis=1)
# ---> 14 df.columns = ['cif',
#      15             'chi_nhanh',
#      16             'ten_khach_hang',
#      17             'tinh_chat', 'no_cu_no_moi',
#      18             'no_nq42', 'nhom_no', 'du_no',
#      19             'gia_tri_tsbd_ho_so_vay',
#      20             'gia_tri_tsbd_dinh_gia_gan_nhat',
#      21             'tinh_chat_ho_so_vay_theo_tsbd',
#      22              'bien_phap_xu_ly', 'tinh_trang_to_tung',
# ...

# %%
df['date_report'] = date(2023,9,30)
df.gia_tri_tsbd_dinh_gia_gan_nhat = df.gia_tri_tsbd_dinh_gia_gan_nhat.astype(str).str.replace(',','')
df.gia_tri_tsbd_dinh_gia_gan_nhat = df.gia_tri_tsbd_dinh_gia_gan_nhat.astype(str).str.replace('.','')
df.kha_thu_lai = df.kha_thu_lai.astype(str).str.replace('.','')
df.gia_tri_tsbd_dinh_gia_gan_nhat = df.gia_tri_tsbd_dinh_gia_gan_nhat.astype(str).apply(lambda x: float(x) if x.strip() != '-' else None)
df.kha_thu_lai = df.kha_thu_lai.astype(str).apply(lambda x: float(x) if x.strip() != '-' else None)
display(df.info())
df.to_sql('tinh_hinh_xu_ly_no_nhom_nho_le',con=conn, index=False, schema='dmt', if_exists='append')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 718 entries, 0 to 717
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   cif                             718 non-null    object
#  1   chi_nhanh                       718 non-null    object
#  2   ten_khach_hang                  718 non-null    object
#  3   tinh_chat                       718 non-null    object
#  4   no_cu_no_moi                    718 non-null    object
#  5   no_nq42                         718 non-null    object
#  6   nhom_no                         632 non-null    float64
#  7   du_no                           718 non-null    float64
#  8   gia_tri_tsbd_ho_so_vay          718 non-null    float64
#  9   gia_tri_tsbd_dinh_gia_gan_nhat  718 non-null    float64
#  10  tinh_chat_ho_so_vay_theo_tsbd   664 non-null    object
#  11  bien_phap_xu_ly                 680 non-null    object
# ...

# %% [markdown]
# # NamDH làm

# %% [markdown]
# ## 31/10/2023

# %%
import pandas as pd
import numpy as np
from unidecode import unidecode
from datetime import date
from sqlalchemy import create_engine
conn = create_engine('postgresql+psycopg2://postgres:Baohoai123%40@192.168.1.123/cbquant')

df = pd.read_excel('./xln_file/2023-11-03_B.CN_TINH HINH XU LY NHOM NHO LE - 31102023.xlsx', sheet_name='Sheet1', skiprows=5)
df = df[2:].reset_index(drop=True)
df = df.dropna(subset=['CIF']).reset_index(drop=True)         # để df[2:] thì không cần [1:] ở đây
df = df.drop(['Phòng Giao Dịch'], axis=1)
df = df.drop(['Nguyên nhân quá hạn\n(- Do SXKD thua lỗ;\n- Do khách hàng thất nghiệp;\n- Do……)',
       'Tình hình khách hàng, hồ sơ cho vay, TSBĐ…',
       'Tổng quan tình hình xử lý\n(Nêu khái quát tình hình, nổi bật kết quả đến thời điểm báo cáo)'], axis=1)

df.columns = ['cif', 
            'chi_nhanh', 
            'ten_khach_hang',
            'tinh_chat', 'no_cu_no_moi',
            'no_nq42', 'nhom_no', 'du_no', 
            'gia_tri_tsbd_ho_so_vay',
            'gia_tri_tsbd_dinh_gia_gan_nhat', 
            'tinh_chat_ho_so_vay_theo_tsbd',
             'bien_phap_xu_ly', 'tinh_trang_to_tung',
            # 'nguyen_nhan_qua_han',
            # 'qua_trinh_xu_ly',
            # 'kho_khan_vuong_mac',      
            # 'tong_quan_tinh_hinh_xu_ly',
            # 'kien_nghi',
            'phan_nhom_mau_sac', 
            'kha_thu_goc', 
            'kha_thu_lai',
            'mat_goc', 
            'ty_le_kha_thu_goc_du_no_goc',
            # 'yeu_to_lam_cham',
            'tinh_trang_ho_so', 
            'ten_cbpt',
            'nam_phat_sinh_no_xau']

# %% [markdown]
# ### Nam note chi tiết

# %%
# import các thư viện 
import pandas as pd
#from unidecode import unidecode
from datetime import date
from sqlalchemy import create_engine

# %%
# chọn cấu hình - nơi sẽ đổ data vào sau khi xử lý tại Notebook
conn = create_engine('postgresql+psycopg2://postgres:Baohoai123%40@192.168.1.123/cbquant')

# %%
# tải dữ liệu từ file excel vào Notebook để xử lý
# sheet_name chỉ đích danh sheet được load vào, chỉ load được 1 sheet
# skiprows số dòng bỏ qua trước đi đến header 

df = pd.read_excel('2023-11-03_B.CN_TINH HINH XU LY NHOM NHO LE - 31102023.xlsx',
                   sheet_name='Sheet1', 
                   skiprows=5)

# %%
df
# Out:
#                   CIF     Chi nhánh Phòng Giao Dịch      Tên khách hàng  \
# 0                 NaN           NaN             NaN                 NaN
# 1                 (1)             2               3                 (4)
# 2       DANG NGOC ANH  CN RACH KIEN    CN RACH KIEN       DANG NGOC ANH
# 3    PHUNG MINH LUONG  CN RACH KIEN    CN RACH KIEN    PHUNG MINH LUONG
# 4      NGUYEN THI HAI  CN RACH KIEN    CN RACH KIEN      NGUYEN THI HAI
# ..                ...           ...             ...                 ...
# 793        0310007429     CN HA NOI     PGD DOI CAN    LE THI NGOC DIEP
# 794        0360017146     CN HA NOI  PGD THANG LONG       TRAN VAN TIEP
# 795        0310019899     CN HA NOI     PGD DOI CAN  PHAM THI HONG HANH
# 796        0360019698     CN HA NOI  PGD THANG LONG    TRIEU QUANG HANH
# 797               NaN           NaN             NaN                 NaN
#
#     - Nội bảng;\n- VAMC;\n- Nhận lại nợ từ VAMC NỢ CŨ/NỢ MỚI  \
# ...

# %%
#đếm số giá trị trong cột bằng .value_counts()
df['Khả thu lãi'].value_counts()
# Out:
# Khả thu lãi
# -              431
# 0               16
# 500000000        4
# 300000000        2
# 40000000         2
#               ...
# 119275845        1
# 208703350        1
# 9445559          1
# 200309554        1
# 44583109283      1
# Name: count, Length: 64, dtype: int64

# %%
# xóa 2 dòng đầu là Row1. NaN (do bị merge với dòng header và Row2 là lỗi do (1) (2) (3) (4)
df = df[2:].reset_index(drop=True)
df
# Out:
#                   CIF     Chi nhánh Phòng Giao Dịch           Tên khách hàng  \
# 0       DANG NGOC ANH  CN RACH KIEN    CN RACH KIEN            DANG NGOC ANH
# 1    PHUNG MINH LUONG  CN RACH KIEN    CN RACH KIEN         PHUNG MINH LUONG
# 2      NGUYEN THI HAI  CN RACH KIEN    CN RACH KIEN           NGUYEN THI HAI
# 3          0100089888    CN SAI GON      CN SAI GON  CTY CP THUONG MAI S.V.C
# 4          6200001436  CN LAM GIANG    CN LAM GIANG           NGUYEN VAN NAM
# ..                ...           ...             ...                      ...
# 791        0310007429     CN HA NOI     PGD DOI CAN         LE THI NGOC DIEP
# 792        0360017146     CN HA NOI  PGD THANG LONG            TRAN VAN TIEP
# 793        0310019899     CN HA NOI     PGD DOI CAN       PHAM THI HONG HANH
# 794        0360019698     CN HA NOI  PGD THANG LONG         TRIEU QUANG HANH
# 795               NaN           NaN             NaN                      NaN
#
# ...

# %%
# bỏ những cột nơi có CIF là null và hàng đầu tiên là (1) (2) (3) (4) (nhưng một số lần bị nhầm là KH DANG NGOC ANH) [1:]
df = df.dropna(subset=['CIF']).reset_index(drop=True)
df
# Out:
#                   CIF     Chi nhánh Phòng Giao Dịch           Tên khách hàng  \
# 0       DANG NGOC ANH  CN RACH KIEN    CN RACH KIEN            DANG NGOC ANH
# 1    PHUNG MINH LUONG  CN RACH KIEN    CN RACH KIEN         PHUNG MINH LUONG
# 2      NGUYEN THI HAI  CN RACH KIEN    CN RACH KIEN           NGUYEN THI HAI
# 3          0100089888    CN SAI GON      CN SAI GON  CTY CP THUONG MAI S.V.C
# 4          6200001436  CN LAM GIANG    CN LAM GIANG           NGUYEN VAN NAM
# ..                ...           ...             ...                      ...
# 790        0310021403     CN HA NOI     PGD DOI CAN             TRAN VAN SAU
# 791        0310007429     CN HA NOI     PGD DOI CAN         LE THI NGOC DIEP
# 792        0360017146     CN HA NOI  PGD THANG LONG            TRAN VAN TIEP
# 793        0310019899     CN HA NOI     PGD DOI CAN       PHAM THI HONG HANH
# 794        0360019698     CN HA NOI  PGD THANG LONG         TRIEU QUANG HANH
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 794 entries, 0 to 793
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   cif                             794 non-null    object
#  1   chi_nhanh                       794 non-null    object
#  2   ten_khach_hang                  794 non-null    object
#  3   tinh_chat                       794 non-null    object
#  4   no_cu_no_moi                    794 non-null    object
#  5   no_nq42                         794 non-null    object
#  6   nhom_no                         711 non-null    float64
#  7   du_no                           794 non-null    float64
#  8   gia_tri_tsbd_ho_so_vay          794 non-null    float64
#  9   gia_tri_tsbd_dinh_gia_gan_nhat  700 non-null    object
#  10  tinh_chat_ho_so_vay_theo_tsbd   792 non-null    object
#  11  bien_phap_xu_ly                 718 non-null    object
# ...

# %%
# drop các cột không cần thiết
df = df.drop(['Phòng Giao Dịch'], axis=1)
df = df.drop(['Nguyên nhân quá hạn\n(- Do SXKD thua lỗ;\n- Do khách hàng thất nghiệp;\n- Do……)',
       'Tình hình khách hàng, hồ sơ cho vay, TSBĐ…',
       'Tổng quan tình hình xử lý\n(Nêu khái quát tình hình, nổi bật kết quả đến thời điểm báo cáo)'], axis=1)

df.columns = ['cif', 
            'chi_nhanh', 
            'ten_khach_hang',
            'tinh_chat', 'no_cu_no_moi',
            'no_nq42', 'nhom_no', 'du_no', 
            'gia_tri_tsbd_ho_so_vay',
            'gia_tri_tsbd_dinh_gia_gan_nhat', 
            'tinh_chat_ho_so_vay_theo_tsbd',
             'bien_phap_xu_ly', 'tinh_trang_to_tung',
            # 'nguyen_nhan_qua_han',
            # 'qua_trinh_xu_ly',
            # 'kho_khan_vuong_mac',      
            # 'tong_quan_tinh_hinh_xu_ly',
            # 'kien_nghi',
            'phan_nhom_mau_sac', 
            'kha_thu_goc', 
            'kha_thu_lai',
            'mat_goc', 
            'ty_le_kha_thu_goc_du_no_goc',
            # 'yeu_to_lam_cham',
            'tinh_trang_ho_so', 
            'ten_cbpt',
            'nam_phat_sinh_no_xau']
df
# Out:
#                   cif     chi_nhanh           ten_khach_hang        tinh_chat  \
# 0    PHUNG MINH LUONG  CN RACH KIEN         PHUNG MINH LUONG       DA SD DPRR
# 1      NGUYEN THI HAI  CN RACH KIEN           NGUYEN THI HAI       DA SD DPRR
# 2          0100089888    CN SAI GON  CTY CP THUONG MAI S.V.C  VAMC_MUA LAI NO
# 3          6200001436  CN LAM GIANG           NGUYEN VAN NAM  VAMC_MUA LAI NO
# 4          0400015190    CN SAI GON          HOANG NGOC TUAN  VAMC_MUA LAI NO
# ..                ...           ...                      ...              ...
# 789        0310021403     CN HA NOI             TRAN VAN SAU         NOI BANG
# 790        0310007429     CN HA NOI         LE THI NGOC DIEP         NOI BANG
# 791        0360017146     CN HA NOI            TRAN VAN TIEP         NOI BANG
# 792        0310019899     CN HA NOI       PHAM THI HONG HANH         NOI BANG
# 793        0360019698     CN HA NOI         TRIEU QUANG HANH         NOI BANG
#
# ...

# %%
# lọc các giá trị là string trong cột gia_tri_tsbd_dinh_gia_gan_nhat (vì cột này là object type)
for ipp in df.iloc[:,9]:  #or df[‘gia_tri_tsbd_dinh_gia_gan_nhat’]
    if type(ipp) == str:
        print(ipp)
# Out:
# TS01: 354.730.000
# TS02: 1.829.308.000
# TS01: 4.825.000.000
# TS02: 1.744.274.292
# TS01: 2.903.544.000
# TS01: 4.266.432.000
# 1,675,460,000
# 6,256,740,000
# 10,089,000,000
# 7,762,248,660
# 6.207.600.000
# 3,539,000,000
#
#
#
#
#
#
# 1,910,000,000
#
#
#
#
#
#
# 2,050,000,000
#
#
#
#
#
#
# 4,500,000,000
# 1.579.700.200
# 4.387.575.296
# 1.961.105.395
# 2.000.887.178
# 760.000.000
# 6.370.000.000
# 3.500.000.000
# 1.600.000.000
# 7.600.000.000
# 7.600.000.000
# 4.080.000.000
# 7.172.000.000
# 7.033.000.000

# %%
# lọc các giá trị là string trong cột kha_thu_lai (vì cột này là object type)
for ipp in df['kha_thu_lai']:
    if type(ipp) == str:
        print(ipp)
# Out:
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# 2.000.000.000
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
#  -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# ...

# %%
# show một vài dòng bị phế
df.iloc[203:210,9]
# Out:
# 203                                  1576000000
# 204      TS01: 354.730.000\nTS02: 1.829.308.000
# 205    TS01: 4.825.000.000\nTS02: 1.744.274.292
# 206                                  1552973909
# 207                                  3176260000
# 208                                  3297346843
# 209    TS01: 2.903.544.000\nTS01: 4.266.432.000
# Name: gia_tri_tsbd_dinh_gia_gan_nhat, dtype: object

# %%
# thay thế các string trong cột gia_tri_tsbd_dinh_gia_gan_nhat bằng cách cộng thủ công
df.iloc[204,9] = 6569274292
#'TS01: 4.825.000.000\nTS02: 1.744.274.292'
df.iloc[205,9] = 2184038000
#'TS01: 354.730.000\nTS02: 1.829.308.000'
df.iloc[209,9] = 7169976000
#'TS01: 2.903.544.000\nTS01: 4.266.432.000'
df.iloc[482,9] = 11999000000
#df.iloc[482,9] = np.NaN
#'3539000000\n\n\n\n\n\n\n1910000000\n\n\n\n\n\n\n2050000000\n\n\n\n\n\n\n4500000000'

# %%
# thêm cột date_report là ngày cuối tháng báo cáo
df['date_report'] = date(2023,10,31)
df
# Out:
#                   cif     chi_nhanh           ten_khach_hang        tinh_chat  \
# 0    PHUNG MINH LUONG  CN RACH KIEN         PHUNG MINH LUONG       DA SD DPRR
# 1      NGUYEN THI HAI  CN RACH KIEN           NGUYEN THI HAI       DA SD DPRR
# 2          0100089888    CN SAI GON  CTY CP THUONG MAI S.V.C  VAMC_MUA LAI NO
# 3          6200001436  CN LAM GIANG           NGUYEN VAN NAM  VAMC_MUA LAI NO
# 4          0400015190    CN SAI GON          HOANG NGOC TUAN  VAMC_MUA LAI NO
# ..                ...           ...                      ...              ...
# 789        0310021403     CN HA NOI             TRAN VAN SAU         NOI BANG
# 790        0310007429     CN HA NOI         LE THI NGOC DIEP         NOI BANG
# 791        0360017146     CN HA NOI            TRAN VAN TIEP         NOI BANG
# 792        0310019899     CN HA NOI       PHAM THI HONG HANH         NOI BANG
# 793        0360019698     CN HA NOI         TRIEU QUANG HANH         NOI BANG
#
# ...

# %%
# thêm cột yeu_to_lam_cham là NaN/ không cần cũng đc vì khi đổ data vào sql tự động mặc định là nan
df['yeu_to_lam_cham'] = np.NaN

# %%
# xóa các dấu "," và "." trong cột gia_tri_tsbd_dinh_gia_gan_nhat (vì cột này là object type)
df.gia_tri_tsbd_dinh_gia_gan_nhat = df.gia_tri_tsbd_dinh_gia_gan_nhat.astype(str).str.replace('.','')
df.gia_tri_tsbd_dinh_gia_gan_nhat = df.gia_tri_tsbd_dinh_gia_gan_nhat.astype(str).str.replace(',','').astype(float)

# %%
# xóa các dấu "." và thay thế các giá trị "-" thành Null trong cột kha_thu_lai (vì cột này là object type)
df.kha_thu_lai = df.kha_thu_lai.astype(str).str.replace('.','')
df.kha_thu_lai = df.kha_thu_lai.astype(str).apply(lambda x: float(x) if x.strip() != '-' else None)

# %%
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 794 entries, 0 to 793
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   cif                             794 non-null    object
#  1   chi_nhanh                       794 non-null    object
#  2   ten_khach_hang                  794 non-null    object
#  3   tinh_chat                       794 non-null    object
#  4   no_cu_no_moi                    794 non-null    object
#  5   no_nq42                         794 non-null    object
#  6   nhom_no                         711 non-null    float64
#  7   du_no                           794 non-null    float64
#  8   gia_tri_tsbd_ho_so_vay          794 non-null    float64
#  9   gia_tri_tsbd_dinh_gia_gan_nhat  700 non-null    float64
#  10  tinh_chat_ho_so_vay_theo_tsbd   792 non-null    object
#  11  bien_phap_xu_ly                 718 non-null    object
# ...

# %%
# chọn bảng, schema để đổ data vào postgreSQL, nếu đã tồn tại thì thêm tiếp data vào bảng đó, không tạo bảng mới
df.to_sql('tinh_hinh_xu_ly_no_nhom_nho_le',con=conn, index=False, schema='dmt', if_exists='append')

# %% [markdown]
# ### note tiếp:

# %%
df = pd.read_excel('2023-08-02_B.CN_TINH HINH XU LY NHOM NHO LE - 31072023.xlsx', sheet_name='Sheet1', skiprows=5)
df = df.drop(['Phòng Giao Dịch'], axis=1)
df
# Out:
#                   CIF     Chi nhánh    Tên khách hàng  \
# 0                 NaN           NaN               NaN
# 1                 (1)             2               (4)
# 2       DANG NGOC ANH  CN RACH KIEN     DANG NGOC ANH
# 3    PHUNG MINH LUONG  CN RACH KIEN  PHUNG MINH LUONG
# 4      NGUYEN THI HAI  CN RACH KIEN    NGUYEN THI HAI
# ..                ...           ...               ...
# 645        4170038809    CN SAI GON      LE TRUNG SON
# 646        0640013556    CN DA NANG  DAM VAN QUOC LAM
# 647        4120021721    CN SAI GON  LE THI QUYNH CHI
# 648        0310026862     CN HA NOI      DAO THI THUY
# 649               NaN           NaN               NaN
#
#     - Nội bảng;\n- VAMC;\n- Nhận lại nợ từ VAMC NỢ CŨ/NỢ MỚI  \
# 0                                           NaN          NaN
# 1                                             5            6
# 2                                    DA SD DPRR        NO CU
# 3                                    DA SD DPRR        NO CU
# ...

# %%
replace(['male', 'female'],[1, 0], inplace=True)

# %% [markdown]
# ## Tiếp 30/10/2023

# %%
for ipp in df.iloc[:,9]:  #or df[‘gia_tri_tsbd_dinh_gia_gan_nhat’]
    if type(ipp) == str:
        print(ipp)
# Out:
# TS01: 354.730.000
# TS02: 1.829.308.000
# TS01: 4.825.000.000
# TS02: 1.744.274.292
# TS01: 2.903.544.000
# TS01: 4.266.432.000
# 1,675,460,000
# 6,256,740,000
# 10,089,000,000
# 7,762,248,660
# 6.207.600.000
# 3,539,000,000
#
#
#
#
#
#
# 1,910,000,000
#
#
#
#
#
#
# 2,050,000,000
#
#
#
#
#
#
# 4,500,000,000
# 1.579.700.200
# 4.387.575.296
# 1.961.105.395
# 2.000.887.178
# 760.000.000
# 6.370.000.000
# 3.500.000.000
# 1.600.000.000
# 7.600.000.000
# 7.600.000.000
# 4.080.000.000
# 7.172.000.000
# 7.033.000.000

# %%
df.iloc[203:210,9]
# Out:
# 203                                  1576000000
# 204      TS01: 354.730.000\nTS02: 1.829.308.000
# 205    TS01: 4.825.000.000\nTS02: 1.744.274.292
# 206                                  1552973909
# 207                                  3176260000
# 208                                  3297346843
# 209    TS01: 2.903.544.000\nTS01: 4.266.432.000
# Name: gia_tri_tsbd_dinh_gia_gan_nhat, dtype: object

# %%
# thay thế các string trong cột gia_tri_tsbd_dinh_gia_gan_nhat 
df.iloc[204,9] = 6569274292
#'TS01: 4.825.000.000\nTS02: 1.744.274.292'
df.iloc[205,9] = 2184038000
#'TS01: 354.730.000\nTS02: 1.829.308.000'
df.iloc[209,9] = 7169976000
#'TS01: 2.903.544.000\nTS01: 4.266.432.000'
df.iloc[482,9] = 11999000000
#df.iloc[482,9] = np.NaN
#'3539000000\n\n\n\n\n\n\n1910000000\n\n\n\n\n\n\n2050000000\n\n\n\n\n\n\n4500000000'

# %%
df['date_report'] = date(2023,10,31)
df['yeu_to_lam_cham'] = np.NaN
df.gia_tri_tsbd_dinh_gia_gan_nhat = df.gia_tri_tsbd_dinh_gia_gan_nhat.astype(str).str.replace('.','')
df.gia_tri_tsbd_dinh_gia_gan_nhat = df.gia_tri_tsbd_dinh_gia_gan_nhat.astype(str).str.replace(',','').astype(float)
df.kha_thu_lai = df.kha_thu_lai.astype(str).str.replace('.','')
df.kha_thu_lai = df.kha_thu_lai.astype(str).apply(lambda x: float(x) if x.strip() != '-' else None)
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 794 entries, 0 to 793
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   cif                             794 non-null    object
#  1   chi_nhanh                       794 non-null    object
#  2   ten_khach_hang                  794 non-null    object
#  3   tinh_chat                       794 non-null    object
#  4   no_cu_no_moi                    794 non-null    object
#  5   no_nq42                         794 non-null    object
#  6   nhom_no                         711 non-null    float64
#  7   du_no                           794 non-null    float64
#  8   gia_tri_tsbd_ho_so_vay          794 non-null    float64
#  9   gia_tri_tsbd_dinh_gia_gan_nhat  700 non-null    float64
#  10  tinh_chat_ho_so_vay_theo_tsbd   792 non-null    object
#  11  bien_phap_xu_ly                 718 non-null    object
# ...

# %%
df.to_sql('tinh_hinh_xu_ly_no_nhom_nho_le',con=conn, index=False, schema='dmt', if_exists='append')
# Out:
# 794

# %% [markdown]
# ## Bản Remake không xóa các trường như anh Khôi bảo

# %% [markdown]
# ### Ngày 30/04/2023

# %%
# chọn cấu hình - nơi sẽ đổ data vào sau khi xử lý tại Notebook
conn = create_engine('postgresql+psycopg2://postgres:Baohoai123%40@192.168.1.123/cbquant')
df = pd.read_excel('./xln_file/2023-04-30_B.CN_TINH HINH XU LY NHOM NHO LE - 30042023.xlsx',
                   sheet_name='CHI TIET TINH HINH XU LY', 
                   skiprows=3)

# %%
import pandas as pd
import numpy as np
# from unidecode import unidecode
from datetime import date
from sqlalchemy import create_engine

df = pd.read_excel('2023-04-30_B.CN_TINH HINH XU LY NHOM NHO LE - 30042023.xlsx',
                   sheet_name='CHI TIET TINH HINH XU LY', 
                   skiprows=3)  
df
# Out:
#                   CIF     Chi nhánh            Tên khách hàng  \
# 0                 NaN           NaN                       NaN
# 1                 (1)             2                         3
# 2       DANG NGOC ANH  CN RACH KIEN             DANG NGOC ANH
# 3    PHUNG MINH LUONG  CN RACH KIEN          PHUNG MINH LUONG
# 4      NGUYEN THI HAI  CN RACH KIEN            NGUYEN THI HAI
# ..                ...           ...                       ...
# 543        0350030995     CN HA NOI       NGUYEN THI HAI BINH
# 544        0350033280     CN HA NOI             LE THI PHUONG
# 545        0300095519     CN HA NOI             VU TRUNG KIEN
# 546        0300134643     CN HA NOI  CTCP CONG NGHIEP SAO BAC
# 547               NaN           NaN                       NaN
#
#     - Nội bảng;\n- VAMC;\n- Nhận lại nợ từ VAMC NỢ CŨ/NỢ MỚI  \
# 0                                           NaN          NaN
# 1                                           (4)            5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 548 entries, 0 to 547
# Data columns (total 28 columns):
#  #   Column                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                      --------------  -----
#  0   CIF                                                                                         546 non-null    object
#  1   Chi nhánh                                                                                   546 non-null    object
#  2   Tên khách hàng                                                                              546 non-null    object
#  3   - Nội bảng;
# - VAMC;
# - Nhận lại nợ từ VAMC                                                   546 non-null    object
#  4   NỢ CŨ/NỢ MỚI                                                                                546 non-null    object
# ...

# %%
df = df[2:].reset_index(drop=True)
df = df.dropna(subset=['CIF']).iloc[:,:-1].reset_index(drop=True)  #cột ngoài cùng có vấn đề
df['phong_giao_dich'] = np.NaN

df.columns = ['cif',
            'chi_nhanh',  
            'ten_khach_hang',
            'tinh_chat', 
            'no_cu_no_moi',
            'no_nq42',
            'nhom_no',
            'du_no',
            'gia_tri_tsbd_ho_so_vay',
            'gia_tri_tsbd_dinh_gia_gan_nhat',
            'tinh_chat_ho_so_vay_theo_tsbd',
            'bien_phap_xu_ly',
            'tinh_trang_to_tung',
            'nguyen_nhan_qua_han',
            'qua_trinh_xu_ly',
            'tong_quan_tinh_hinh_xu_ly',
            'kho_khan_vuong_mac',
            'kien_nghi',
            'phan_nhom_mau_sac',
            'kha_thu_goc',
            'kha_thu_lai',
            'mat_goc',
            'ty_le_kha_thu_goc_du_no_goc',
            'yeu_to_lam_cham',
            'tinh_trang_ho_so',
            'ten_cbpt',
            'nam_phat_sinh_no_xau',
            'phong_giao_dich']
df.head()
# Out:
#                 cif      chi_nhanh    ten_khach_hang   tinh_chat no_cu_no_moi  \
# 0     DANG NGOC ANH   CN RACH KIEN     DANG NGOC ANH  DA SD DPRR        NO CU
# 1  PHUNG MINH LUONG   CN RACH KIEN  PHUNG MINH LUONG  DA SD DPRR        NO CU
# 2    NGUYEN THI HAI   CN RACH KIEN    NGUYEN THI HAI  DA SD DPRR        NO CU
# 3        2110000631     CN LONG AN     BUI DUY QUANG    NOI BANG        NO CU
# 4        6000047063  CN KIEN GIANG     BUI HOANG ANH    NOI BANG       NO MOI
#
#             no_nq42  nhom_no        du_no  gia_tri_tsbd_ho_so_vay  \
# 0        THUOC NQ42      NaN    2499000.0                     0.0
# 1        THUOC NQ42      NaN     800000.0                     0.0
# 2        THUOC NQ42      NaN    4100000.0                     0.0
# 3        THUOC NQ42      5.0   13300000.0                     0.0
# 4  KHONG THUOC NQ42      2.0  619240220.0             865412891.0
#
#   gia_tri_tsbd_dinh_gia_gan_nhat  ... phan_nhom_mau_sac  kha_thu_goc  \
# ...

# %%
df = df[['cif',
            'chi_nhanh',
            'phong_giao_dich',
            'ten_khach_hang',
            'tinh_chat', 
            'no_cu_no_moi',
            'no_nq42',
            'nhom_no',
            'du_no',
            'gia_tri_tsbd_ho_so_vay',
            'gia_tri_tsbd_dinh_gia_gan_nhat',
            'tinh_chat_ho_so_vay_theo_tsbd',
            'bien_phap_xu_ly',
            'tinh_trang_to_tung',
            'nguyen_nhan_qua_han',
            'qua_trinh_xu_ly',
            'tong_quan_tinh_hinh_xu_ly',
            'kho_khan_vuong_mac',
            'kien_nghi',
            'phan_nhom_mau_sac',
            'kha_thu_goc',
            'kha_thu_lai',
            'mat_goc',
            'ty_le_kha_thu_goc_du_no_goc',
            'yeu_to_lam_cham',
            'tinh_trang_ho_so',
            'ten_cbpt',
            'nam_phat_sinh_no_xau']]

# %%
df
# Out:
#                   cif      chi_nhanh  phong_giao_dich  \
# 0       DANG NGOC ANH   CN RACH KIEN              NaN
# 1    PHUNG MINH LUONG   CN RACH KIEN              NaN
# 2      NGUYEN THI HAI   CN RACH KIEN              NaN
# 3          2110000631     CN LONG AN              NaN
# 4          6000047063  CN KIEN GIANG              NaN
# ..                ...            ...              ...
# 540        0300129957      CN HA NOI              NaN
# 541        0350030995      CN HA NOI              NaN
# 542        0350033280      CN HA NOI              NaN
# 543        0300095519      CN HA NOI              NaN
# 544        0300134643      CN HA NOI              NaN
#
#                ten_khach_hang   tinh_chat no_cu_no_moi           no_nq42  \
# 0               DANG NGOC ANH  DA SD DPRR        NO CU        THUOC NQ42
# 1            PHUNG MINH LUONG  DA SD DPRR        NO CU        THUOC NQ42
# 2              NGUYEN THI HAI  DA SD DPRR        NO CU        THUOC NQ42
# ...

# %%
# lọc các giá trị là string trong cột gia_tri_tsbd_dinh_gia_gan_nhat (vì cột này là object type)
for ipp in df['gia_tri_tsbd_dinh_gia_gan_nhat']:  #df.iloc[:,10]:
    if type(ipp) == str:
        print(ipp)
# Out:
# 457,500,000

# %%
# lọc các giá trị là string trong cột kha_thu_lai (nếu cột này là object type)
for ipp in df['kha_thu_lai']:
    if type(ipp) == str:
        print(ipp)

# %%
#df.gia_tri_tsbd_dinh_gia_gan_nhat = df.gia_tri_tsbd_dinh_gia_gan_nhat.astype(str).str.replace('.','')
#df.kha_thu_lai = df.kha_thu_lai.astype(str).str.replace('.','')

df.gia_tri_tsbd_dinh_gia_gan_nhat = df.gia_tri_tsbd_dinh_gia_gan_nhat.astype(str).str.replace(',','').astype(float)
#df.kha_thu_lai = df.kha_thu_lai.astype(str).apply(lambda x: float(x) if x.strip() != '-' else None)
df.yeu_to_lam_cham = df.yeu_to_lam_cham.map({'Y':True, 'N':False})
df['date_report'] = date(2023,4,30)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   cif                             545 non-null    object
#  1   chi_nhanh                       545 non-null    object
#  2   phong_giao_dich                 0 non-null      float64
#  3   ten_khach_hang                  545 non-null    object
#  4   tinh_chat                       545 non-null    object
#  5   no_cu_no_moi                    545 non-null    object
#  6   no_nq42                         545 non-null    object
#  7   nhom_no                         514 non-null    float64
#  8   du_no                           545 non-null    float64
#  9   gia_tri_tsbd_ho_so_vay          545 non-null    float64
#  10  gia_tri_tsbd_dinh_gia_gan_nhat  545 non-null    float64
#  11  tinh_chat_ho_so_vay_theo_tsbd   545 non-null    object
# ...

# %%
df.to_sql('tinh_hinh_xu_ly_no_nhom_nho_le_2',con=conn, index=False, schema='dmt', if_exists='append')

# %% [markdown]
# ### Ngày 31/05/2023

# %%
# chọn cấu hình - nơi sẽ đổ data vào sau khi xử lý tại Notebook
conn = create_engine('postgresql+psycopg2://postgres:Baohoai123%40@192.168.1.123/cbquant')
df = pd.read_excel('./xln_file/2023-05-31_B.CN_TINH HINH XU LY NHOM NHO LE - 31052023.xlsx',
                   sheet_name='Sheet1', 
                   skiprows=5)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[34], line 2
#       1 # chọn cấu hình - nơi sẽ đổ data vào sau khi xử lý tại Notebook
# ----> 2 conn = create_engine('postgresql+psycopg2://postgres:Baohoai123%40@192.168.1.123/cbquant')
#       3 df = pd.read_excel('./xln_file/2023-05-31_B.CN_TINH HINH XU LY NHOM NHO LE - 31052023.xlsx',
#       4                    sheet_name='Sheet1',
#       5                    skiprows=3)
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sqlalchemy\util\deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
# ...

# %%
import pandas as pd
# from unidecode import unidecode
from datetime import date
from sqlalchemy import create_engine

df = pd.read_excel('2023-05-31_B.CN_TINH HINH XU LY NHOM NHO LE - 31052023.xlsx',
                   sheet_name='Sheet1', 
                   skiprows=5)  
df
# Out:
#                   CIF      Chi nhánh Phòng Giao Dịch     Tên khách hàng  \
# 0                 NaN            NaN             NaN                NaN
# 1                 (1)              2               3                (4)
# 2       DANG NGOC ANH   CN RACH KIEN    CN RACH KIEN      DANG NGOC ANH
# 3    PHUNG MINH LUONG   CN RACH KIEN    CN RACH KIEN   PHUNG MINH LUONG
# 4      NGUYEN THI HAI   CN RACH KIEN    CN RACH KIEN     NGUYEN THI HAI
# ..                ...            ...             ...                ...
# 560        0900057621  CN TIEN GIANG   CN TIEN GIANG   NGUYEN THI BE BA
# 561        3020008775     CN BEN TRE      PGD BA TRI  NGUYEN TUAN PHONG
# 562        3020008995     CN BEN TRE      PGD BA TRI   PHAM THI YEN NHI
# 563        7000056840    CN TRA VINH     CN TRA VINH     NGUYEN HAI DAO
# 564               NaN            NaN             NaN               TỔNG
#
#     - Nội bảng;\n- VAMC;\n- Nhận lại nợ từ VAMC NỢ CŨ/NỢ MỚI  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 565 entries, 0 to 564
# Data columns (total 28 columns):
#  #   Column                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                      --------------  -----
#  0   CIF                                                                                         563 non-null    object
#  1   Chi nhánh                                                                                   563 non-null    object
#  2   Phòng Giao Dịch                                                                             563 non-null    object
#  3   Tên khách hàng                                                                              564 non-null    object
#  4   - Nội bảng;
# - VAMC;
# - Nhận lại nợ từ VAMC                                                   563 non-null    object
# ...

# %%
df = df[2:].reset_index(drop=True)
df = df.dropna(subset=['CIF']).reset_index(drop=True)

df.columns = ['cif',
            'chi_nhanh', 
            'phong_giao_dich',  
            'ten_khach_hang',
            'tinh_chat', 
            'no_cu_no_moi',
            'no_nq42',
            'nhom_no',
            'du_no',
            'gia_tri_tsbd_ho_so_vay',
            'gia_tri_tsbd_dinh_gia_gan_nhat',
            'tinh_chat_ho_so_vay_theo_tsbd',
            'bien_phap_xu_ly',
            'tinh_trang_to_tung',
            'nguyen_nhan_qua_han',
            'qua_trinh_xu_ly',
            'tong_quan_tinh_hinh_xu_ly',
            'kho_khan_vuong_mac',
            'kien_nghi',
            'phan_nhom_mau_sac',
            'kha_thu_goc',
            'kha_thu_lai',
            'mat_goc',
            'ty_le_kha_thu_goc_du_no_goc',
            'yeu_to_lam_cham',
            'tinh_trang_ho_so',
            'ten_cbpt',
            'nam_phat_sinh_no_xau']

# %%
# lọc các giá trị là string trong cột gia_tri_tsbd_dinh_gia_gan_nhat (vì cột này là object type)
for ipp in df['gia_tri_tsbd_dinh_gia_gan_nhat']:  #df.iloc[:,10]:
    if type(ipp) == str:
        print(ipp)

# %%
#df.gia_tri_tsbd_dinh_gia_gan_nhat = df.gia_tri_tsbd_dinh_gia_gan_nhat.astype(str).str.replace('.','')
#df.kha_thu_lai = df.kha_thu_lai.astype(str).str.replace('.','')

df.gia_tri_tsbd_dinh_gia_gan_nhat = df.gia_tri_tsbd_dinh_gia_gan_nhat.astype(str).str.replace(',','').astype(float)
#df.kha_thu_lai = df.kha_thu_lai.astype(str).apply(lambda x: float(x) if x.strip() != '-' else None)
df.yeu_to_lam_cham = df.yeu_to_lam_cham.map({'Y':True, 'N':False})
df['date_report'] = date(2023,5,31)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 562 entries, 0 to 561
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   cif                             562 non-null    object
#  1   chi_nhanh                       562 non-null    object
#  2   phong_giao_dich                 562 non-null    object
#  3   ten_khach_hang                  562 non-null    object
#  4   tinh_chat                       562 non-null    object
#  5   no_cu_no_moi                    562 non-null    object
#  6   no_nq42                         562 non-null    object
#  7   nhom_no                         515 non-null    float64
#  8   du_no                           562 non-null    float64
#  9   gia_tri_tsbd_ho_so_vay          562 non-null    float64
#  10  gia_tri_tsbd_dinh_gia_gan_nhat  560 non-null    float64
#  11  tinh_chat_ho_so_vay_theo_tsbd   562 non-null    object
# ...

# %%
df.to_sql('tinh_hinh_xu_ly_no_nhom_nho_le_2',con=conn, index=False, schema='dmt', if_exists='append')### Ngày 31/05/2023

# %% [markdown]
# ### Ngày 30/06/2023

# %%
# chọn cấu hình - nơi sẽ đổ data vào sau khi xử lý tại Notebook
conn = create_engine('postgresql+psycopg2://postgres:Baohoai123%40@192.168.1.123/cbquant')
df = pd.read_excel('./xln_file/2023-06-30_B.CN_TINH HINH XU LY NHOM NHO LE - 30062023.xlsx',
                   sheet_name='Sheet1', 
                   skiprows=3)

# %%
import pandas as pd
# from unidecode import unidecode
from datetime import date
from sqlalchemy import create_engine

df = pd.read_excel('2023-06-30_B.CN_TINH HINH XU LY NHOM NHO LE - 30062023.xlsx',
                   sheet_name='Sheet1', 
                   skiprows=5)  
df
# Out:
#                   CIF     Chi nhánh Phòng Giao Dịch        Tên khách hàng  \
# 0                 NaN           NaN             NaN                   NaN
# 1                 (1)             2               3                   (4)
# 2       DANG NGOC ANH  CN RACH KIEN    CN RACH KIEN         DANG NGOC ANH
# 3    PHUNG MINH LUONG  CN RACH KIEN    CN RACH KIEN      PHUNG MINH LUONG
# 4      NGUYEN THI HAI  CN RACH KIEN    CN RACH KIEN        NGUYEN THI HAI
# ..                ...           ...             ...                   ...
# 624        6200028248  CN LAM GIANG             NaN    TRAN THI NGOC TRAM
# 625        3030008215    CN BEN TRE             NaN        NGUYEN THUY AN
# 626        0150002402  CN RACH KIEN             NaN  NGUYEN THI KIM HUONG
# 627        0290152009    CN LONG AN             NaN    NGUYEN LE QUOC ANH
# 628         TỔNG CỘNG           NaN             NaN                   NaN
#
#     - Nội bảng;\n- VAMC;\n- Nhận lại nợ từ VAMC NỢ CŨ/NỢ MỚI  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 629 entries, 0 to 628
# Data columns (total 28 columns):
#  #   Column                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                      --------------  -----
#  0   CIF                                                                                         628 non-null    object
#  1   Chi nhánh                                                                                   627 non-null    object
#  2   Phòng Giao Dịch                                                                             616 non-null    object
#  3   Tên khách hàng                                                                              627 non-null    object
#  4   - Nội bảng;
# - VAMC;
# - Nhận lại nợ từ VAMC                                                   627 non-null    object
# ...

# %%
df = df[2:].reset_index(drop=True)
df = df.dropna(subset=['CIF']).reset_index(drop=True)

df.columns = ['cif',
            'chi_nhanh', 
            'phong_giao_dich',  
            'ten_khach_hang',
            'tinh_chat', 
            'no_cu_no_moi',
            'no_nq42',
            'nhom_no',
            'du_no',
            'gia_tri_tsbd_ho_so_vay',
            'gia_tri_tsbd_dinh_gia_gan_nhat',
            'tinh_chat_ho_so_vay_theo_tsbd',
            'bien_phap_xu_ly',
            'tinh_trang_to_tung',
            'nguyen_nhan_qua_han',
            'qua_trinh_xu_ly',
            'tong_quan_tinh_hinh_xu_ly',
            'kho_khan_vuong_mac',
            'kien_nghi',
            'phan_nhom_mau_sac',
            'kha_thu_goc',
            'kha_thu_lai',
            'mat_goc',
            'ty_le_kha_thu_goc_du_no_goc',
            'yeu_to_lam_cham',
            'tinh_trang_ho_so',
            'ten_cbpt',
            'nam_phat_sinh_no_xau']

# %%
# lọc các giá trị là string trong cột gia_tri_tsbd_dinh_gia_gan_nhat (vì cột này là object type)
for ipp in df['gia_tri_tsbd_dinh_gia_gan_nhat']:  #df.iloc[:,10]:
    if type(ipp) == str:
        print(ipp)

# %%
#df.gia_tri_tsbd_dinh_gia_gan_nhat = df.gia_tri_tsbd_dinh_gia_gan_nhat.astype(str).str.replace('.','')
#df.kha_thu_lai = df.kha_thu_lai.astype(str).str.replace('.','')

df.gia_tri_tsbd_dinh_gia_gan_nhat = df.gia_tri_tsbd_dinh_gia_gan_nhat.astype(str).str.replace(',','').astype(float)
#df.kha_thu_lai = df.kha_thu_lai.astype(str).apply(lambda x: float(x) if x.strip() != '-' else None)
df.yeu_to_lam_cham = df.yeu_to_lam_cham.map({'Y':True, 'N':False})
df['date_report'] = date(2023,6,30)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 627 entries, 0 to 626
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   cif                             627 non-null    object
#  1   chi_nhanh                       626 non-null    object
#  2   phong_giao_dich                 615 non-null    object
#  3   ten_khach_hang                  626 non-null    object
#  4   tinh_chat                       626 non-null    object
#  5   no_cu_no_moi                    626 non-null    object
#  6   no_nq42                         626 non-null    object
#  7   nhom_no                         557 non-null    float64
#  8   du_no                           627 non-null    float64
#  9   gia_tri_tsbd_ho_so_vay          627 non-null    float64
#  10  gia_tri_tsbd_dinh_gia_gan_nhat  627 non-null    float64
#  11  tinh_chat_ho_so_vay_theo_tsbd   626 non-null    object
# ...

# %%
df
# Out:
#                   cif      chi_nhanh phong_giao_dich        ten_khach_hang  \
# 0       DANG NGOC ANH   CN RACH KIEN    CN RACH KIEN         DANG NGOC ANH
# 1    PHUNG MINH LUONG   CN RACH KIEN    CN RACH KIEN      PHUNG MINH LUONG
# 2      NGUYEN THI HAI   CN RACH KIEN    CN RACH KIEN        NGUYEN THI HAI
# 3          2110000631     CN LONG AN     PGD DUC HOA         BUI DUY QUANG
# 4          6000047063  CN KIEN GIANG   CN KIEN GIANG         BUI HOANG ANH
# ..                ...            ...             ...                   ...
# 622        6200028248   CN LAM GIANG             NaN    TRAN THI NGOC TRAM
# 623        3030008215     CN BEN TRE             NaN        NGUYEN THUY AN
# 624        0150002402   CN RACH KIEN             NaN  NGUYEN THI KIM HUONG
# 625        0290152009     CN LONG AN             NaN    NGUYEN LE QUOC ANH
# 626         TỔNG CỘNG            NaN             NaN                   NaN
#
# ...

# %%
df.to_sql('tinh_hinh_xu_ly_no_nhom_nho_le_2',con=conn, index=False, schema='dmt', if_exists='append')

# %% [markdown]
# ### Ngày 31/07/2023

# %%
# chọn cấu hình - nơi sẽ đổ data vào sau khi xử lý tại Notebook
conn = create_engine('postgresql+psycopg2://postgres:Baohoai123%40@192.168.1.123/cbquant')
df = pd.read_excel('./xln_file/2023-08-02_B.CN_TINH HINH XU LY NHOM NHO LE - 31072023.xlsx',
                   sheet_name='Sheet1', 
                   skiprows=3)

# %%
import pandas as pd
# from unidecode import unidecode
from datetime import date
from sqlalchemy import create_engine

df = pd.read_excel('2023-08-02_B.CN_TINH HINH XU LY NHOM NHO LE - 31072023.xlsx',
                   sheet_name='Sheet1', 
                   skiprows=5)  
df
# Out:
#                   CIF     Chi nhánh Phòng Giao Dịch    Tên khách hàng  \
# 0                 NaN           NaN             NaN               NaN
# 1                 (1)             2               3               (4)
# 2       DANG NGOC ANH  CN RACH KIEN    CN RACH KIEN     DANG NGOC ANH
# 3    PHUNG MINH LUONG  CN RACH KIEN    CN RACH KIEN  PHUNG MINH LUONG
# 4      NGUYEN THI HAI  CN RACH KIEN    CN RACH KIEN    NGUYEN THI HAI
# ..                ...           ...             ...               ...
# 645        4170038809    CN SAI GON  PGD MINH PHUNG      LE TRUNG SON
# 646        0640013556    CN DA NANG    PGD SONG HAN  DAM VAN QUOC LAM
# 647        4120021721    CN SAI GON  PGD MINH PHUNG  LE THI QUYNH CHI
# 648        0310026862     CN HA NOI     PGD DOI CAN      DAO THI THUY
# 649               NaN           NaN             NaN               NaN
#
#     - Nội bảng;\n- VAMC;\n- Nhận lại nợ từ VAMC NỢ CŨ/NỢ MỚI  \
# 0                                           NaN          NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 650 entries, 0 to 649
# Data columns (total 28 columns):
#  #   Column                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                      --------------  -----
#  0   CIF                                                                                         648 non-null    object
#  1   Chi nhánh                                                                                   648 non-null    object
#  2   Phòng Giao Dịch                                                                             648 non-null    object
#  3   Tên khách hàng                                                                              648 non-null    object
#  4   - Nội bảng;
# - VAMC;
# - Nhận lại nợ từ VAMC                                                   648 non-null    object
# ...

# %%
df = df[2:].reset_index(drop=True)
df = df.dropna(subset=['CIF']).reset_index(drop=True)

df.columns = ['cif',
            'chi_nhanh', 
            'phong_giao_dich',  
            'ten_khach_hang',
            'tinh_chat', 
            'no_cu_no_moi',
            'no_nq42',
            'nhom_no',
            'du_no',
            'gia_tri_tsbd_ho_so_vay',
            'gia_tri_tsbd_dinh_gia_gan_nhat',
            'tinh_chat_ho_so_vay_theo_tsbd',
            'bien_phap_xu_ly',
            'tinh_trang_to_tung',
            'nguyen_nhan_qua_han',
            'qua_trinh_xu_ly',
            'tong_quan_tinh_hinh_xu_ly',
            'kho_khan_vuong_mac',
            'kien_nghi',
            'phan_nhom_mau_sac',
            'kha_thu_goc',
            'kha_thu_lai',
            'mat_goc',
            'ty_le_kha_thu_goc_du_no_goc',
            'yeu_to_lam_cham',
            'tinh_trang_ho_so',
            'ten_cbpt',
            'nam_phat_sinh_no_xau']

# %%
# lọc các giá trị là string trong cột gia_tri_tsbd_dinh_gia_gan_nhat (vì cột này là object type)
for ipp in df['gia_tri_tsbd_dinh_gia_gan_nhat']:  #df.iloc[:,10]:
    if type(ipp) == str:
        print(ipp)

# %%
for ipp in df['kha_thu_lai']:  #df.iloc[:,10]:
    if type(ipp) == str:
        print(ipp)
# Out:
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# ...

# %%
#df.gia_tri_tsbd_dinh_gia_gan_nhat = df.gia_tri_tsbd_dinh_gia_gan_nhat.astype(str).str.replace('.','')
#df.kha_thu_lai = df.kha_thu_lai.astype(str).str.replace('.','')

df.gia_tri_tsbd_dinh_gia_gan_nhat = df.gia_tri_tsbd_dinh_gia_gan_nhat.astype(str).str.replace(',','').astype(float)
df.kha_thu_lai = df.kha_thu_lai.astype(str).apply(lambda x: float(x) if x.strip() != '-' else None)
df.yeu_to_lam_cham = df.yeu_to_lam_cham.map({'Y':True, 'N':False})
df['date_report'] = date(2023,7,31)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 647 entries, 0 to 646
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   cif                             647 non-null    object
#  1   chi_nhanh                       647 non-null    object
#  2   phong_giao_dich                 647 non-null    object
#  3   ten_khach_hang                  647 non-null    object
#  4   tinh_chat                       647 non-null    object
#  5   no_cu_no_moi                    647 non-null    object
#  6   no_nq42                         647 non-null    object
#  7   nhom_no                         575 non-null    float64
#  8   du_no                           647 non-null    float64
#  9   gia_tri_tsbd_ho_so_vay          647 non-null    float64
#  10  gia_tri_tsbd_dinh_gia_gan_nhat  647 non-null    float64
#  11  tinh_chat_ho_so_vay_theo_tsbd   647 non-null    object
# ...

# %%
df
# Out:
#                   cif     chi_nhanh phong_giao_dich           ten_khach_hang  \
# 0       DANG NGOC ANH  CN RACH KIEN    CN RACH KIEN            DANG NGOC ANH
# 1    PHUNG MINH LUONG  CN RACH KIEN    CN RACH KIEN         PHUNG MINH LUONG
# 2      NGUYEN THI HAI  CN RACH KIEN    CN RACH KIEN           NGUYEN THI HAI
# 3          0100089888    CN SAI GON      CN SAI GON  CTY CP THUONG MAI S.V.C
# 4          6200001436  CN LAM GIANG    CN LAM GIANG           NGUYEN VAN NAM
# ..                ...           ...             ...                      ...
# 642        3030006024    CN BEN TRE   PGD DONG KHOI          NGUYEN VAN HUNG
# 643        4170038809    CN SAI GON  PGD MINH PHUNG             LE TRUNG SON
# 644        0640013556    CN DA NANG    PGD SONG HAN         DAM VAN QUOC LAM
# 645        4120021721    CN SAI GON  PGD MINH PHUNG         LE THI QUYNH CHI
# 646        0310026862     CN HA NOI     PGD DOI CAN             DAO THI THUY
#
# ...

# %%
df.to_sql('tinh_hinh_xu_ly_no_nhom_nho_le_2',con=conn, index=False, schema='dmt', if_exists='append')

# %% [markdown]
# ### Ngày 31/08/2023

# %%
# chọn cấu hình - nơi sẽ đổ data vào sau khi xử lý tại Notebook
conn = create_engine('postgresql+psycopg2://postgres:Baohoai123%40@192.168.1.123/cbquant')
df = pd.read_excel('./xln_file/2023-09-07_B.CN_TINH HINH XU LY NHOM NHO LE - 31082023.xlsx',
                   sheet_name='Sheet1', 
                   skiprows=3)

# %%
import pandas as pd
# from unidecode import unidecode
from datetime import date
from sqlalchemy import create_engine

df = pd.read_excel('2023-09-07_B.CN_TINH HINH XU LY NHOM NHO LE - 31082023.xlsx',
                   sheet_name='Sheet1', 
                   skiprows=5)  
df
# Out:
#                   CIF     Chi nhánh Phòng Giao Dịch       Tên khách hàng  \
# 0                 NaN           NaN             NaN                  NaN
# 1                 (1)             2               3                  (4)
# 2       DANG NGOC ANH  CN RACH KIEN    CN RACH KIEN        DANG NGOC ANH
# 3    PHUNG MINH LUONG  CN RACH KIEN    CN RACH KIEN     PHUNG MINH LUONG
# 4      NGUYEN THI HAI  CN RACH KIEN    CN RACH KIEN       NGUYEN THI HAI
# ..                ...           ...             ...                  ...
# 674        0360019698     CN HA NOI  PGD THANG LONG     TRIEU QUANG HANH
# 675        0350030995     CN HA NOI     PGD HAO NAM  NGUYEN THI HAI BINH
# 676        0350033280     CN HA NOI     PGD HAO NAM        LE THI PHUONG
# 677        0350034731     CN HA NOI     PGD HAO NAM         DO HUU QUANG
# 678               NaN           NaN             NaN                  NaN
#
#     - Nội bảng;\n- VAMC;\n- Nhận lại nợ từ VAMC NỢ CŨ/NỢ MỚI  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 679 entries, 0 to 678
# Data columns (total 25 columns):
#  #   Column                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                      --------------  -----
#  0   CIF                                                                                         677 non-null    object
#  1   Chi nhánh                                                                                   677 non-null    object
#  2   Phòng Giao Dịch                                                                             677 non-null    object
#  3   Tên khách hàng                                                                              677 non-null    object
#  4   - Nội bảng;
# - VAMC;
# - Nhận lại nợ từ VAMC                                                   677 non-null    object
# ...

# %%
df = df[2:].reset_index(drop=True)
df = df.dropna(subset=['CIF']).reset_index(drop=True)

df.columns = ['cif',
            'chi_nhanh', 
            'phong_giao_dich',  
            'ten_khach_hang',
            'tinh_chat', 
            'no_cu_no_moi',
            'no_nq42',
            'nhom_no',
            'du_no',
            'gia_tri_tsbd_ho_so_vay',
            'gia_tri_tsbd_dinh_gia_gan_nhat',
            'tinh_chat_ho_so_vay_theo_tsbd',
            'bien_phap_xu_ly',
            'tinh_trang_to_tung',
            'nguyen_nhan_qua_han',
            'kho_khan_vuong_mac',
            #'qua_trinh_xu_ly',
            'tong_quan_tinh_hinh_xu_ly',
            #'kien_nghi',
            'phan_nhom_mau_sac',
            'kha_thu_goc',
            'kha_thu_lai',
            'mat_goc',
            'ty_le_kha_thu_goc_du_no_goc',
            #'yeu_to_lam_cham',
            'tinh_trang_ho_so',
            'ten_cbpt',
            'nam_phat_sinh_no_xau']

# %%
df
# Out:
#                   cif     chi_nhanh phong_giao_dich  \
# 0       DANG NGOC ANH  CN RACH KIEN    CN RACH KIEN
# 1    PHUNG MINH LUONG  CN RACH KIEN    CN RACH KIEN
# 2      NGUYEN THI HAI  CN RACH KIEN    CN RACH KIEN
# 3          0400008402    CN SAI GON      CN SAI GON
# 4          0400013057    CN SAI GON      CN SAI GON
# ..                ...           ...             ...
# 671        0310019899     CN HA NOI     PGD DOI CAN
# 672        0360019698     CN HA NOI  PGD THANG LONG
# 673        0350030995     CN HA NOI     PGD HAO NAM
# 674        0350033280     CN HA NOI     PGD HAO NAM
# 675        0350034731     CN HA NOI     PGD HAO NAM
#
#                                       ten_khach_hang        tinh_chat  \
# 0                                      DANG NGOC ANH       DA SD DPRR
# 1                                   PHUNG MINH LUONG       DA SD DPRR
# 2                                     NGUYEN THI HAI       DA SD DPRR
# ...

# %%
# lọc các giá trị là string trong cột gia_tri_tsbd_dinh_gia_gan_nhat (vì cột này là object type)
for ipp in df['gia_tri_tsbd_dinh_gia_gan_nhat']:  #df.iloc[:,10]:
    if type(ipp) == str:
        print(ipp)
# Out:
# 1,675,460,000
# 6,256,740,000
# 10,089,000,000
# 7,762,248,660

# %%
df['yeu_to_lam_cham'] = np.NaN
df['qua_trinh_xu_ly'] = np.NaN
df['kien_nghi'] = np.NaN

# %%
#df.gia_tri_tsbd_dinh_gia_gan_nhat = df.gia_tri_tsbd_dinh_gia_gan_nhat.astype(str).str.replace('.','')
#df.kha_thu_lai = df.kha_thu_lai.astype(str).str.replace('.','')

df.gia_tri_tsbd_dinh_gia_gan_nhat = df.gia_tri_tsbd_dinh_gia_gan_nhat.astype(str).str.replace(',','').astype(float)
df.kha_thu_lai = df.kha_thu_lai.astype(str).str.replace('.','')
df.kha_thu_lai = df.kha_thu_lai.astype(str).apply(lambda x: float(x) if x.strip() != '-' else None)
df.yeu_to_lam_cham = df.yeu_to_lam_cham.map({'Y':True, 'N':False})
df['date_report'] = date(2023,8,31)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 676 entries, 0 to 675
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   cif                             676 non-null    object
#  1   chi_nhanh                       676 non-null    object
#  2   phong_giao_dich                 676 non-null    object
#  3   ten_khach_hang                  676 non-null    object
#  4   tinh_chat                       676 non-null    object
#  5   no_cu_no_moi                    676 non-null    object
#  6   no_nq42                         676 non-null    object
#  7   nhom_no                         603 non-null    float64
#  8   du_no                           676 non-null    float64
#  9   gia_tri_tsbd_ho_so_vay          676 non-null    float64
#  10  gia_tri_tsbd_dinh_gia_gan_nhat  543 non-null    float64
#  11  tinh_chat_ho_so_vay_theo_tsbd   619 non-null    object
# ...

# %%
df
# Out:
#                   cif     chi_nhanh phong_giao_dich  \
# 0       DANG NGOC ANH  CN RACH KIEN    CN RACH KIEN
# 1    PHUNG MINH LUONG  CN RACH KIEN    CN RACH KIEN
# 2      NGUYEN THI HAI  CN RACH KIEN    CN RACH KIEN
# 3          0400008402    CN SAI GON      CN SAI GON
# 4          0400013057    CN SAI GON      CN SAI GON
# ..                ...           ...             ...
# 671        0310019899     CN HA NOI     PGD DOI CAN
# 672        0360019698     CN HA NOI  PGD THANG LONG
# 673        0350030995     CN HA NOI     PGD HAO NAM
# 674        0350033280     CN HA NOI     PGD HAO NAM
# 675        0350034731     CN HA NOI     PGD HAO NAM
#
#                                       ten_khach_hang        tinh_chat  \
# 0                                      DANG NGOC ANH       DA SD DPRR
# 1                                   PHUNG MINH LUONG       DA SD DPRR
# 2                                     NGUYEN THI HAI       DA SD DPRR
# ...

# %%
df.to_sql('tinh_hinh_xu_ly_no_nhom_nho_le_2',con=conn, index=False, schema='dmt', if_exists='append')

# %% [markdown]
# ### Ngày 30/09/2023

# %%
# chọn cấu hình - nơi sẽ đổ data vào sau khi xử lý tại Notebook
conn = create_engine('postgresql+psycopg2://postgres:Baohoai123%40@192.168.1.123/cbquant')
df = pd.read_excel('./xln_file/2023-10-05_B.CN_TINH HINH XU LY NHOM NHO LE - 30092023.xlsx',
                   sheet_name='Sheet1', 
                   skiprows=5)

# %%
import pandas as pd
# from unidecode import unidecode
from datetime import date
from sqlalchemy import create_engine

df = pd.read_excel('2023-10-05_B.CN_TINH HINH XU LY NHOM NHO LE - 30092023.xlsx',
                   sheet_name='Sheet1', 
                   skiprows=5)  
df
# Out:
#                   CIF     Chi nhánh Phòng Giao Dịch       Tên khách hàng  \
# 0                 NaN           NaN             NaN                  NaN
# 1                 (1)             2               3                  (4)
# 2       DANG NGOC ANH  CN RACH KIEN    CN RACH KIEN        DANG NGOC ANH
# 3    PHUNG MINH LUONG  CN RACH KIEN    CN RACH KIEN     PHUNG MINH LUONG
# 4      NGUYEN THI HAI  CN RACH KIEN    CN RACH KIEN       NGUYEN THI HAI
# ..                ...           ...             ...                  ...
# 717        0360019698     CN HA NOI  PGD THANG LONG     TRIEU QUANG HANH
# 718        0350030995     CN HA NOI     PGD HAO NAM  NGUYEN THI HAI BINH
# 719        0350033280     CN HA NOI     PGD HAO NAM        LE THI PHUONG
# 720        0350034731     CN HA NOI     PGD HAO NAM         DO HUU QUANG
# 721               NaN           NaN             NaN                  NaN
#
#     - Nội bảng;\n- VAMC;\n- Nhận lại nợ từ VAMC NỢ CŨ/NỢ MỚI  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 719 entries, 0 to 718
# Data columns (total 25 columns):
#  #   Column                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                      --------------  -----
#  0   CIF                                                                                         719 non-null    object
#  1   Chi nhánh                                                                                   719 non-null    object
#  2   Phòng Giao Dịch                                                                             719 non-null    object
#  3   Tên khách hàng                                                                              719 non-null    object
#  4   - Nội bảng;
# - VAMC;
# - Nhận lại nợ từ VAMC                                                   719 non-null    object
# ...

# %%
df = df[2:].reset_index(drop=True)
df = df.dropna(subset=['CIF']).reset_index(drop=True)

df.columns = ['cif',
            'chi_nhanh', 
            'phong_giao_dich',  
            'ten_khach_hang',
            'tinh_chat', 
            'no_cu_no_moi',
            'no_nq42',
            'nhom_no',
            'du_no',
            'gia_tri_tsbd_ho_so_vay',
            'gia_tri_tsbd_dinh_gia_gan_nhat',
            'tinh_chat_ho_so_vay_theo_tsbd',
            'bien_phap_xu_ly',
            'tinh_trang_to_tung',
            'nguyen_nhan_qua_han',
            'kho_khan_vuong_mac',
            #'qua_trinh_xu_ly',
            'tong_quan_tinh_hinh_xu_ly',
            #'kien_nghi',
            'phan_nhom_mau_sac',
            'kha_thu_goc',
            'kha_thu_lai',
            'mat_goc',
            'ty_le_kha_thu_goc_du_no_goc',
            #'yeu_to_lam_cham',
            'tinh_trang_ho_so',
            'ten_cbpt',
            'nam_phat_sinh_no_xau']

# %%
# lọc các giá trị là string trong cột gia_tri_tsbd_dinh_gia_gan_nhat (vì cột này là object type)
for ipp in df['gia_tri_tsbd_dinh_gia_gan_nhat']:  #df.iloc[:,10]:
    if type(ipp) == str:
        print(ipp)
# Out:
# 1,675,460,000
# 6,256,740,000
# 10,089,000,000
# 7,762,248,660
# 6.207.600.000

# %%
df['yeu_to_lam_cham'] = np.NaN
df['qua_trinh_xu_ly'] = np.NaN
df['kien_nghi'] = np.NaN

# %%
df.gia_tri_tsbd_dinh_gia_gan_nhat = df.gia_tri_tsbd_dinh_gia_gan_nhat.astype(str).str.replace('.','')
df.kha_thu_lai = df.kha_thu_lai.astype(str).str.replace('.','')

df.gia_tri_tsbd_dinh_gia_gan_nhat = df.gia_tri_tsbd_dinh_gia_gan_nhat.astype(str).str.replace(',','').astype(float)
df.kha_thu_lai = df.kha_thu_lai.astype(str).apply(lambda x: float(x) if x.strip() != '-' else None)
df.yeu_to_lam_cham = df.yeu_to_lam_cham.map({'Y':True, 'N':False})
df['date_report'] = date(2023,9,30)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   cif                             717 non-null    object
#  1   chi_nhanh                       717 non-null    object
#  2   phong_giao_dich                 717 non-null    object
#  3   ten_khach_hang                  717 non-null    object
#  4   tinh_chat                       717 non-null    object
#  5   no_cu_no_moi                    717 non-null    object
#  6   no_nq42                         717 non-null    object
#  7   nhom_no                         632 non-null    float64
#  8   du_no                           717 non-null    float64
#  9   gia_tri_tsbd_ho_so_vay          717 non-null    float64
#  10  gia_tri_tsbd_dinh_gia_gan_nhat  717 non-null    float64
#  11  tinh_chat_ho_so_vay_theo_tsbd   663 non-null    object
# ...

# %%
df
# Out:
#                 cif     chi_nhanh phong_giao_dich           ten_khach_hang  \
# 0    NGUYEN THI HAI  CN RACH KIEN    CN RACH KIEN           NGUYEN THI HAI
# 1        0100089888    CN SAI GON      CN SAI GON  CTY CP THUONG MAI S.V.C
# 2        6200001436  CN LAM GIANG    CN LAM GIANG           NGUYEN VAN NAM
# 3        0400015190    CN SAI GON      CN SAI GON          HOANG NGOC TUAN
# 4        0400014522    CN SAI GON      CN SAI GON     NGUYEN THI HONG HANH
# ..              ...           ...             ...                      ...
# 712      0310019899     CN HA NOI     PGD DOI CAN       PHAM THI HONG HANH
# 713      0360019698     CN HA NOI  PGD THANG LONG         TRIEU QUANG HANH
# 714      0350030995     CN HA NOI     PGD HAO NAM      NGUYEN THI HAI BINH
# 715      0350033280     CN HA NOI     PGD HAO NAM            LE THI PHUONG
# 716      0350034731     CN HA NOI     PGD HAO NAM             DO HUU QUANG
#
# ...

# %%
df.to_sql('tinh_hinh_xu_ly_no_nhom_nho_le_2',con=conn, index=False, schema='dmt', if_exists='append')

# %% [markdown]
# ### Ngày 31/10/2023

# %%
# chọn cấu hình - nơi sẽ đổ data vào sau khi xử lý tại Notebook
conn = create_engine('postgresql+psycopg2://postgres:Baohoai123%40@192.168.1.123/cbquant')
df = pd.read_excel('./xln_file/2023-11-03_B.CN_TINH HINH XU LY NHOM NHO LE - 31102023.xlsx',
                   sheet_name='Sheet1', 
                   skiprows=5)

# %%
import pandas as pd
# from unidecode import unidecode
from datetime import date
from sqlalchemy import create_engine

df = pd.read_excel('2023-11-03_B.CN_TINH HINH XU LY NHOM NHO LE - 31102023.xlsx',
                   sheet_name='Sheet1', 
                   skiprows=5)  
df
# Out:
#                   CIF     Chi nhánh Phòng Giao Dịch      Tên khách hàng  \
# 0                 NaN           NaN             NaN                 NaN
# 1                 (1)             2               3                 (4)
# 2       DANG NGOC ANH  CN RACH KIEN    CN RACH KIEN       DANG NGOC ANH
# 3    PHUNG MINH LUONG  CN RACH KIEN    CN RACH KIEN    PHUNG MINH LUONG
# 4      NGUYEN THI HAI  CN RACH KIEN    CN RACH KIEN      NGUYEN THI HAI
# ..                ...           ...             ...                 ...
# 793        0310007429     CN HA NOI     PGD DOI CAN    LE THI NGOC DIEP
# 794        0360017146     CN HA NOI  PGD THANG LONG       TRAN VAN TIEP
# 795        0310019899     CN HA NOI     PGD DOI CAN  PHAM THI HONG HANH
# 796        0360019698     CN HA NOI  PGD THANG LONG    TRIEU QUANG HANH
# 797               NaN           NaN             NaN                 NaN
#
#     - Nội bảng;\n- VAMC;\n- Nhận lại nợ từ VAMC NỢ CŨ/NỢ MỚI  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 798 entries, 0 to 797
# Data columns (total 25 columns):
#  #   Column                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                      --------------  -----
#  0   CIF                                                                                         796 non-null    object
#  1   Chi nhánh                                                                                   796 non-null    object
#  2   Phòng Giao Dịch                                                                             796 non-null    object
#  3   Tên khách hàng                                                                              796 non-null    object
#  4   - Nội bảng;
# - VAMC;
# - Nhận lại nợ từ VAMC                                                   796 non-null    object
# ...

# %%
df = df[2:].reset_index(drop=True)
df = df.dropna(subset=['CIF']).reset_index(drop=True)

df.columns = ['cif',
            'chi_nhanh', 
            'phong_giao_dich',  
            'ten_khach_hang',
            'tinh_chat', 
            'no_cu_no_moi',
            'no_nq42',
            'nhom_no',
            'du_no',
            'gia_tri_tsbd_ho_so_vay',
            'gia_tri_tsbd_dinh_gia_gan_nhat',
            'tinh_chat_ho_so_vay_theo_tsbd',
            'bien_phap_xu_ly',
            'tinh_trang_to_tung',
            'nguyen_nhan_qua_han',
            'kho_khan_vuong_mac',
            #'qua_trinh_xu_ly',
            'tong_quan_tinh_hinh_xu_ly',
            #'kien_nghi',
            'phan_nhom_mau_sac',
            'kha_thu_goc',
            'kha_thu_lai',
            'mat_goc',
            'ty_le_kha_thu_goc_du_no_goc',
            #'yeu_to_lam_cham',
            'tinh_trang_ho_so',
            'ten_cbpt',
            'nam_phat_sinh_no_xau']

# %%
# lọc các giá trị là string trong cột gia_tri_tsbd_dinh_gia_gan_nhat (vì cột này là object type)
for ipp in df['gia_tri_tsbd_dinh_gia_gan_nhat']:  #df.iloc[:,10]:
    if type(ipp) == str:
        print(ipp)
# Out:
# TS01: 354.730.000
# TS02: 1.829.308.000
# TS01: 4.825.000.000
# TS02: 1.744.274.292
# TS01: 2.903.544.000
# TS01: 4.266.432.000
# 1,675,460,000
# 6,256,740,000
# 10,089,000,000
# 7,762,248,660
# 6.207.600.000
# 3,539,000,000
#
#
#
#
#
#
# 1,910,000,000
#
#
#
#
#
#
# 2,050,000,000
#
#
#
#
#
#
# 4,500,000,000
# 1.579.700.200
# 4.387.575.296
# 1.961.105.395
# 2.000.887.178
# 760.000.000
# 6.370.000.000
# 3.500.000.000
# 1.600.000.000
# 7.600.000.000
# 7.600.000.000
# 4.080.000.000
# 7.172.000.000
# 7.033.000.000

# %%
for ipp in df['kha_thu_lai']:  #df.iloc[:,10]:
    if type(ipp) == str:
        print(ipp)
# Out:
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# 2.000.000.000
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
#  -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# -
# ...

# %%
# show một vài dòng bị phế
df.iloc[205:212,10]
# Out:
# 205      TS01: 354.730.000\nTS02: 1.829.308.000
# 206    TS01: 4.825.000.000\nTS02: 1.744.274.292
# 207                                  1552973909
# 208                                  3176260000
# 209                                  3297346843
# 210    TS01: 2.903.544.000\nTS01: 4.266.432.000
# 211                                  1818880000
# Name: gia_tri_tsbd_dinh_gia_gan_nhat, dtype: object

# %%
df.iloc[483,10]
# Out:
# 11999000000

# %%
# thay thế các string trong cột gia_tri_tsbd_dinh_gia_gan_nhat bằng cách cộng thủ công
#'TS01: 354.730.000\nTS02: 1.829.308.000'
df.iloc[205,10] = 2184038000
#'TS01: 4.825.000.000\nTS02: 1.744.274.292'
df.iloc[206,10] = 6569274292  
#'TS01: 2.903.544.000\nTS01: 4.266.432.000'
df.iloc[210,10] = 7169976000
#'3539000000\n\n\n\n\n\n\n1910000000\n\n\n\n\n\n\n2050000000\n\n\n\n\n\n\n4500000000'
df.iloc[483,10] = 11999000000

# %%
df['yeu_to_lam_cham'] = np.NaN
df['qua_trinh_xu_ly'] = np.NaN
df['kien_nghi'] = np.NaN

# %%
df.gia_tri_tsbd_dinh_gia_gan_nhat = df.gia_tri_tsbd_dinh_gia_gan_nhat.astype(str).str.replace('.','')
df.kha_thu_lai = df.kha_thu_lai.astype(str).str.replace('.','')

df.gia_tri_tsbd_dinh_gia_gan_nhat = df.gia_tri_tsbd_dinh_gia_gan_nhat.astype(str).str.replace(',','').astype(float)
df.kha_thu_lai = df.kha_thu_lai.astype(str).apply(lambda x: float(x) if x.strip() != '-' else None)
df.yeu_to_lam_cham = df.yeu_to_lam_cham.map({'Y':True, 'N':False})
df['date_report'] = date(2023,10,31)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 795 entries, 0 to 794
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   cif                             795 non-null    object
#  1   chi_nhanh                       795 non-null    object
#  2   phong_giao_dich                 795 non-null    object
#  3   ten_khach_hang                  795 non-null    object
#  4   tinh_chat                       795 non-null    object
#  5   no_cu_no_moi                    795 non-null    object
#  6   no_nq42                         795 non-null    object
#  7   nhom_no                         711 non-null    float64
#  8   du_no                           795 non-null    float64
#  9   gia_tri_tsbd_ho_so_vay          795 non-null    float64
#  10  gia_tri_tsbd_dinh_gia_gan_nhat  701 non-null    float64
#  11  tinh_chat_ho_so_vay_theo_tsbd   793 non-null    object
# ...

# %%
df
# Out:
#                   cif     chi_nhanh phong_giao_dich           ten_khach_hang  \
# 0       DANG NGOC ANH  CN RACH KIEN    CN RACH KIEN            DANG NGOC ANH
# 1    PHUNG MINH LUONG  CN RACH KIEN    CN RACH KIEN         PHUNG MINH LUONG
# 2      NGUYEN THI HAI  CN RACH KIEN    CN RACH KIEN           NGUYEN THI HAI
# 3          0100089888    CN SAI GON      CN SAI GON  CTY CP THUONG MAI S.V.C
# 4          6200001436  CN LAM GIANG    CN LAM GIANG           NGUYEN VAN NAM
# ..                ...           ...             ...                      ...
# 790        0310021403     CN HA NOI     PGD DOI CAN             TRAN VAN SAU
# 791        0310007429     CN HA NOI     PGD DOI CAN         LE THI NGOC DIEP
# 792        0360017146     CN HA NOI  PGD THANG LONG            TRAN VAN TIEP
# 793        0310019899     CN HA NOI     PGD DOI CAN       PHAM THI HONG HANH
# 794        0360019698     CN HA NOI  PGD THANG LONG         TRIEU QUANG HANH
#
# ...

# %%
df.to_sql('tinh_hinh_xu_ly_no_nhom_nho_le_2',con=conn, index=False, schema='dmt', if_exists='append')
